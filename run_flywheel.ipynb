# %%
from data_flywheel import DataFlywheel
# Out:
# /root/miniforge-pypy3/envs/icevision/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# INFO     - The mmdet config folder already exists. No need to downloaded it. Path : /root/.icevision/mmdetection_configs/mmdetection_configs-2.20.1/configs | icevision.models.mmdet.download_configs:download_mmdet_configs:17

# %%
# Create a configuration dictionary
config = {
    'annotation_path': '/root/data-flywheel/notebooks/objectlab/pascal_voc_annotations/',
    'image_path': '/workspace/yolo_v8_training/oiv7_full/validation/',
    'log_wandb': True,
    'wandb_project': 'data-flywheel-test1'
}

# Instantiate the DataFlywheel
flywheel = DataFlywheel(config)
# Out:
# 04/08/2024 12:41:08 - ERROR - wandb.jupyter -   Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: dnth. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/root/data-flywheel/wandb/run-20240408_124109-jl4nc70b</code>
# Syncing run <strong><a href='https://wandb.ai/dnth/data-flywheel-test1/runs/jl4nc70b' target="_blank">daily-bee-15</a></strong> to <a href='https://wandb.ai/dnth/data-flywheel-test1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dnth/data-flywheel-test1' target="_blank">https://wandb.ai/dnth/data-flywheel-test1</a>
#  View run at <a href='https://wandb.ai/dnth/data-flywheel-test1/runs/jl4nc70b' target="_blank">https://wandb.ai/dnth/data-flywheel-test1/runs/jl4nc70b</a>
# wandb: Adding directory to artifact (/root/data-flywheel/notebooks/objectlab/pascal_voc_annotations)... Done. 0.1s

# %%
# flywheel.run()

# %%
flywheel.load_annotations()
# Out:
# INFO     - Loading image annotations... | data_flywheel.flywheel:load_annotations:32
# INFO     -   Annotations folder: /root/data-flywheel/notebooks/objectlab/pascal_voc_annotations/ | data_flywheel.flywheel:load_annotations:34
# INFO     -   Image folder: /workspace/yolo_v8_training/oiv7_full/validation/ | data_flywheel.flywheel:load_annotations:35
#   0%|          | 0/822 [00:00<?, ?it/s]
# INFO     - Autofixing records | icevision.parsers.parser:parse:122
#   0%|          | 0/822 [00:00<?, ?it/s]
# WARNING  - (record_id: 001840a807e454c7) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/001840a807e454c7.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 00770ee8f5ad87ef) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/00770ee8f5ad87ef.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 008216e31b1aecf0) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/008216e31b1aecf0.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 00a42a80e5e8d194) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/00a42a80e5e8d194.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 00ccda615ec9731d) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/00ccda615ec9731d.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 012dc31b561d4214) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/012dc31b561d4214.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 013e4b54ccdf22aa) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/013e4b54ccdf22aa.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 01b187eac8b7b42d) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/01b187eac8b7b42d.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 01ba306be0fb6e3b) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/01ba306be0fb6e3b.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 01ce6a0b84b8ab22) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/01ce6a0b84b8ab22.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0293d27f2c20c95e) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0293d27f2c20c95e.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 02b7e70979560df7) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/02b7e70979560df7.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 02c94402476ac94c) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/02c94402476ac94c.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 02d1d3375f2d3dca) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/02d1d3375f2d3dca.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 02faccbb84bd2bc5) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/02faccbb84bd2bc5.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 02fcc80210b7cd5b) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/02fcc80210b7cd5b.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0321485893e5cf27) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0321485893e5cf27.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 032518c7e3660911) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/032518c7e3660911.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 03650b9fde97f523) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/03650b9fde97f523.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 038ee0bf31929792) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/038ee0bf31929792.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 03f1ef1359dbf0c1) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/03f1ef1359dbf0c1.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 040cdf988e08ed0d) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/040cdf988e08ed0d.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0419739a49a5d743) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0419739a49a5d743.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0438c2d3613680bf) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0438c2d3613680bf.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 043f3655deab6e7c) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/043f3655deab6e7c.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 049720d842de2d3e) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/049720d842de2d3e.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 051d28d0388a3ec1) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/051d28d0388a3ec1.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 053314871c5e46ac) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/053314871c5e46ac.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 05798ca4c1946ae1) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/05798ca4c1946ae1.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 05c6fc62d2980f50) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/05c6fc62d2980f50.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 060cb181e7f669c3) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/060cb181e7f669c3.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 06145d1b37e96fed) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/06145d1b37e96fed.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 067ac2d0c7096ca2) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/067ac2d0c7096ca2.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 06a4a9b49707a673) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/06a4a9b49707a673.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 06aabc23f48f9eaa) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/06aabc23f48f9eaa.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 06c8ed604ebd3b17) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/06c8ed604ebd3b17.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 06e00c35d91450ae) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/06e00c35d91450ae.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 06fc6e41f721a1bf) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/06fc6e41f721a1bf.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0701ff1789905309) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0701ff1789905309.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0787ba239b4ca568) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0787ba239b4ca568.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 081b5acdf94c392a) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/081b5acdf94c392a.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 08402b0168fd57f0) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/08402b0168fd57f0.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0875084906c62ddd) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0875084906c62ddd.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 092f6bd6d306fdf6) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/092f6bd6d306fdf6.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 09625dc24eb205b4) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/09625dc24eb205b4.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 099136489e17c901) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/099136489e17c901.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 09b5c9a79c959dbc) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/09b5c9a79c959dbc.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 09d8aa2d19ff724d) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/09d8aa2d19ff724d.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0a1bd356f90aaab6) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0a1bd356f90aaab6.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0a5972c68b6bb265) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0a5972c68b6bb265.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0ad7bad30cd432df) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0ad7bad30cd432df.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0ae34629c80eb3dd) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0ae34629c80eb3dd.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0b2c23d6ee2b3801) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0b2c23d6ee2b3801.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0b44f28fa177010c) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0b44f28fa177010c.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0b8ae9cfd133e587) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0b8ae9cfd133e587.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0ba3f8b8a3a2e93c) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0ba3f8b8a3a2e93c.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0bb193f2cf957fdd) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0bb193f2cf957fdd.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0bb677e9352aae04) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0bb677e9352aae04.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0bbc0cf4ae824472) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0bbc0cf4ae824472.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0c44911e6b2f48a1) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0c44911e6b2f48a1.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0c8c95f1ed69dcf0) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0c8c95f1ed69dcf0.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0ca8141ebf85044e) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0ca8141ebf85044e.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0cd91641653cf35c) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0cd91641653cf35c.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0cec50a04882cbb6) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0cec50a04882cbb6.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0cfbddbfcf8412a6) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0cfbddbfcf8412a6.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0ddfd840b9f43875) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0ddfd840b9f43875.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0e0a23e811ca026b) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0e0a23e811ca026b.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0eb14d233faf68d2) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0eb14d233faf68d2.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0ec2376f42667511) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0ec2376f42667511.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0ee131f55fb5b7f2) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0ee131f55fb5b7f2.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0f00a73b3614d4d2) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0f00a73b3614d4d2.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0f3c2228fb89a3d2) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0f3c2228fb89a3d2.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0f667cd048230166) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0f667cd048230166.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 0fe036c8ee34fb29) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/0fe036c8ee34fb29.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 100332464ea7f674) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/100332464ea7f674.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 1050b3c3f36090a3) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/1050b3c3f36090a3.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 105894faa652acd5) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/105894faa652acd5.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 10651d2876cd50d8) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/10651d2876cd50d8.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 1089296beeeb1f12) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/1089296beeeb1f12.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 108d42438cde2a78) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/108d42438cde2a78.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 109be5018058e0b6) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/109be5018058e0b6.xml' does not exist | icevision.core.record:autofix_records:100
# WARNING  - (record_id: 10bd0ab74275791f) - 🚫 Record could not be autofixed and will be removed because: File '/workspace/yolo_v8_training/oiv7_full/validation/10bd0ab74275791f.xml' does not exist | icevision.core.record:autofix_records:100
# INFO     -   Train on 592 images | data_flywheel.flywheel:load_annotations:53
# INFO     -   Validate on 148 images | data_flywheel.flywheel:load_annotations:54

# %%
# %matplotlib inline
flywheel.load_model()
# Out:
# INFO     - Loading model... | data_flywheel.flywheel:load_model:57
# 2024-04-08 12:41:12,978 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2024-04-08 12:41:12,979 - mmcv - INFO - load model from: torchvision://resnet50
# 2024-04-08 12:41:12,980 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2024-04-08 12:41:13,029 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2024-04-08 12:41:13,041 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2024-04-08 12:41:13,060 - mmcv - INFO - initialize VFNetHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'vfnet_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2024-04-08 12:41:13,079 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,080 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,080 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,080 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,081 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,081 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,081 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,081 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,082 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,082 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,082 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,082 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,083 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,083 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,083 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,083 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,083 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,084 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,084 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,084 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,084 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,085 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,085 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,085 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,085 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,086 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,086 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,086 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,086 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,087 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,087 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,087 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,087 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,088 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,088 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,088 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,088 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,088 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,089 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,089 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,089 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,089 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,090 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,090 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,090 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,090 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,091 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,091 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,091 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,091 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,092 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,092 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,092 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,092 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,093 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,093 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,093 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,093 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,093 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,094 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,094 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,095 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,095 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,095 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,096 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,096 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,097 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,097 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,097 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,097 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,097 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,098 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,098 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,098 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,098 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,099 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,099 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,099 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,099 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,100 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,100 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,100 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,100 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,101 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,101 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,101 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,101 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,102 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,102 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,102 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,102 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,102 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,103 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,103 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,103 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,103 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,104 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,104 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,104 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,104 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,105 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,105 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,105 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,105 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,105 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,106 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,106 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,106 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,106 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,107 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,107 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,107 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,107 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,108 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,108 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,108 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,108 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,108 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,109 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,109 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,109 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,110 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,110 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,110 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,110 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,110 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,111 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,111 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,111 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,111 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,112 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,112 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,112 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,112 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,113 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,113 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,113 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,113 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,113 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,114 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,114 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,114 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,114 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,115 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,115 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,115 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,115 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,116 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,116 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,116 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,116 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,116 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,117 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,117 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,117 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,117 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,118 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,118 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,118 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2024-04-08 12:41:13,118 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,119 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,119 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,119 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,119 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,120 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,120 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,120 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,120 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,120 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,121 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,121 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,121 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,121 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,122 - mmcv - INFO -
# neck.fpn_convs.4.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2024-04-08 12:41:13,122 - mmcv - INFO -
# neck.fpn_convs.4.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,122 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,122 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,123 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,123 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,123 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,123 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,124 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,124 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,124 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,124 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,124 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,125 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,125 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,125 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,125 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,126 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,126 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,126 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,126 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.conv.weight - torch.Size([256, 256, 3, 3]):
# Initialized by user-defined `init_weights` in ConvModule
#
# 2024-04-08 12:41:13,127 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,127 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,127 - mmcv - INFO -
# bbox_head.vfnet_reg.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,127 - mmcv - INFO -
# bbox_head.vfnet_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,127 - mmcv - INFO -
# bbox_head.scales.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,128 - mmcv - INFO -
# bbox_head.scales.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,128 - mmcv - INFO -
# bbox_head.scales.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,128 - mmcv - INFO -
# bbox_head.scales.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,128 - mmcv - INFO -
# bbox_head.scales.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,129 - mmcv - INFO -
# bbox_head.vfnet_reg_refine_dconv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,129 - mmcv - INFO -
# bbox_head.vfnet_reg_refine.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,129 - mmcv - INFO -
# bbox_head.vfnet_reg_refine.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2024-04-08 12:41:13,129 - mmcv - INFO -
# bbox_head.scales_refine.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,129 - mmcv - INFO -
# bbox_head.scales_refine.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,130 - mmcv - INFO -
# bbox_head.scales_refine.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,130 - mmcv - INFO -
# bbox_head.scales_refine.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,130 - mmcv - INFO -
# bbox_head.scales_refine.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,130 - mmcv - INFO -
# bbox_head.vfnet_cls_dconv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2024-04-08 12:41:13,131 - mmcv - INFO -
# bbox_head.vfnet_cls.weight - torch.Size([1, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2024-04-08 12:41:13,131 - mmcv - INFO -
# bbox_head.vfnet_cls.bias - torch.Size([1]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# INFO     - Finding optimal learning rate.. | data_flywheel.flywheel:load_model:86
# load checkpoint from local path: checkpoints/vfnet/vfnet_r50_fpn_mstrain_2x_coco_20201027-7cc75bd2.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.vfnet_cls.weight: copying a param with shape torch.Size([80, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([1, 256, 3, 3]).
# size mismatch for bbox_head.vfnet_cls.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /root/miniforge-pypy3/envs/icevision/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
flywheel.train_model(lr=3e-4, epoch=10, freeze_epoch=3)
# Out:
# INFO     - Training model... | data_flywheel.flywheel:train_model:90
# Could not gather input dimensions
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'Dataset' object has no attribute 'items'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>COCOMetric</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.033454</td>
#       <td>1.903644</td>
#       <td>0.135273</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.124278</td>
#       <td>1.355531</td>
#       <td>0.481100</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.777211</td>
#       <td>1.361086</td>
#       <td>0.474134</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.9036442041397095.
# Better model found at epoch 1 with valid_loss value: 1.355530858039856.
# Could not gather input dimensions
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>COCOMetric</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.493072</td>
#       <td>1.279544</td>
#       <td>0.512969</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.464001</td>
#       <td>1.274110</td>
#       <td>0.512542</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.446326</td>
#       <td>1.300599</td>
#       <td>0.492710</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.419967</td>
#       <td>1.268253</td>
#       <td>0.522791</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.405311</td>
#       <td>1.275493</td>
#       <td>0.525006</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.366212</td>
#       <td>1.240834</td>
#       <td>0.540199</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.332314</td>
#       <td>1.232939</td>
#       <td>0.542024</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.294170</td>
#       <td>1.234106</td>
#       <td>0.544727</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.262023</td>
#       <td>1.206709</td>
#       <td>0.559885</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.250028</td>
#       <td>1.205551</td>
#       <td>0.557612</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.2795436382293701.
# Better model found at epoch 1 with valid_loss value: 1.2741097211837769.
# Better model found at epoch 3 with valid_loss value: 1.2682527303695679.
# Better model found at epoch 5 with valid_loss value: 1.2408344745635986.
# Better model found at epoch 6 with valid_loss value: 1.2329392433166504.
# Better model found at epoch 8 with valid_loss value: 1.206709384918213.
# Better model found at epoch 9 with valid_loss value: 1.2055506706237793.

# %%
annotations_to_review = flywheel.get_most_wrong(method='top-loss')
# Out:
# INFO     - Identifying most incorrect examples... | data_flywheel.flywheel:get_most_wrong:103
# INFO     - Losses returned by model: ['loss_cls', 'loss_bbox'] | icevision.models.interpretation:plot_top_losses:220
#   0%|          | 0/148 [00:00<?, ?it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# VBox(children=(Label(value='19.689 MB of 55.638 MB uploaded\r'), FloatProgress(value=0.35387576601339, max=1.0…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>COCOMetric</td><td>▁▇▇▇▇▇▇▇█████</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_1</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_3</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_4</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_5</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eps_6</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▁▂▂▃▄▆▇▇█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_1</td><td>▁▂▂▃▄▆▇▇█▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_2</td><td>▁▂▂▃▄▆▇▇█▁▁▁▂▂▂▂▂▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_3</td><td>▁▂▂▃▄▆▇▇█▂▂▂▂▃▃▄▄▄▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>lr_4</td><td>▁▂▂▃▄▅▆▇▇▂▃▃▄▅▆▆▇█████▇▇▇▆▆▅▅▄▄▃▃▂▂▂▁▁▁▁</td></tr><tr><td>lr_5</td><td>▁▁▂▂▂▃▃▄▄▂▃▃▄▅▆▆▇█████▇▇▇▆▆▅▅▄▄▃▃▂▂▂▁▁▁▁</td></tr><tr><td>lr_6</td><td>▁▂▂▃▄▆▇▇█▂▂▂▂▃▃▄▄▄▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>mom_0</td><td>██▇▆▅▄▃▂▁██▇▆▅▄▃▂▁▁▁▁▁▂▂▂▃▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>mom_1</td><td>██▇▆▅▄▃▂▁██▇▆▅▄▃▂▁▁▁▁▁▂▂▂▃▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>mom_2</td><td>██▇▆▅▄▃▂▁██▇▆▅▄▃▂▁▁▁▁▁▂▂▂▃▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>mom_3</td><td>██▇▆▅▄▃▂▁██▇▆▅▄▃▂▁▁▁▁▁▂▂▂▃▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>mom_4</td><td>██▇▆▅▄▃▂▁██▇▆▅▄▃▂▁▁▁▁▁▂▂▂▃▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>mom_5</td><td>██▇▆▅▄▃▂▁██▇▆▅▄▃▂▁▁▁▁▁▂▂▂▃▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>mom_6</td><td>██▇▆▅▄▃▂▁██▇▆▅▄▃▂▁▁▁▁▁▂▂▂▃▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>raw_loss</td><td>██▆▅▃▃▂▂▂▃▂▂▃▂▂▃▂▂▂▁▂▁▂▂▂▂▂▂▁▁▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_1</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_3</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_4</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_5</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_6</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>██▇▆▅▄▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_samples_per_sec</td><td>██████▇██▁▆▆▆▆▆▆▆▆▆▆▆▄▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>valid_loss</td><td>█▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_1</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_2</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_3</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_4</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_5</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>wd_6</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>COCOMetric</td><td>0.55761</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>eps_1</td><td>1e-05</td></tr><tr><td>eps_2</td><td>1e-05</td></tr><tr><td>eps_3</td><td>1e-05</td></tr><tr><td>eps_4</td><td>1e-05</td></tr><tr><td>eps_5</td><td>1e-05</td></tr><tr><td>eps_6</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.0</td></tr><tr><td>lr_1</td><td>0.0</td></tr><tr><td>lr_2</td><td>0.0</td></tr><tr><td>lr_3</td><td>0.0</td></tr><tr><td>lr_4</td><td>0.0</td></tr><tr><td>lr_5</td><td>0.0</td></tr><tr><td>lr_6</td><td>0.0</td></tr><tr><td>mom_0</td><td>0.95</td></tr><tr><td>mom_1</td><td>0.95</td></tr><tr><td>mom_2</td><td>0.95</td></tr><tr><td>mom_3</td><td>0.95</td></tr><tr><td>mom_4</td><td>0.95</td></tr><tr><td>mom_5</td><td>0.95</td></tr><tr><td>mom_6</td><td>0.95</td></tr><tr><td>raw_loss</td><td>1.27122</td></tr><tr ...
#  View run <strong style="color:#cdcd00">daily-bee-15</strong> at: <a href='https://wandb.ai/dnth/data-flywheel-test1/runs/jl4nc70b' target="_blank">https://wandb.ai/dnth/data-flywheel-test1/runs/jl4nc70b</a><br/> View project at: <a href='https://wandb.ai/dnth/data-flywheel-test1' target="_blank">https://wandb.ai/dnth/data-flywheel-test1</a><br/>Synced 5 W&B file(s), 323 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240408_124109-jl4nc70b/logs</code>

# %%
len(flywheel.annotations_to_review)
# Out:
# 148

# %%
flywheel.relabel_data()
# Out:
# INFO     - Launching streamlit to review annotations... | data_flywheel.flywheel:relabel_data:131
# INFO     - Review annotations here: http://0.0.0.0:8501 | data_flywheel.flywheel:relabel_data:132
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 flywheel.relabel_data()
#
# File ~/data-flywheel/data_flywheel/flywheel.py:134, in DataFlywheel.relabel_data(self)
#     131 logger.info("Launching streamlit to review annotations...")
#     132 logger.info("Review annotations here: http://0.0.0.0:8501")
# --> 134 subprocess.run(
#     135     [
#     136         "streamlit",
#     137         "run",
#     138         "data_flywheel/st_relabel.py",
#     139         "--server.address",
#     140         "0.0.0.0",
#     141         "--",
#     142         self.annotation_path,
#     143         self.image_path
#     144     ]
#     145 )
#
# File ~/miniforge-pypy3/envs/icevision/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/miniforge-pypy3/envs/icevision/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/miniforge-pypy3/envs/icevision/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/miniforge-pypy3/envs/icevision/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/miniforge-pypy3/envs/icevision/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:
