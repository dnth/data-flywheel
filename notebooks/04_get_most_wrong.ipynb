# %% [markdown]
# ## Get list of images

# %%
import json

# Path to your JSON file
file_path = '/workspace/datasets/coco_minitrain_25k/annotations/instances_minitrain2017.json'

# Open and load the JSON data
with open(file_path, 'r') as file:
    data = json.load(file)

data['images']
# Out:
# [{'license': 1,
#   'file_name': '000000231538.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000231538.jpg',
#   'height': 640,
#   'width': 476,
#   'date_captured': '2013-11-18 12:00:52',
#   'flickr_url': 'http://farm4.staticflickr.com/3142/2804610447_ec49815f83_z.jpg',
#   'id': 231538},
#  {'license': 5,
#   'file_name': '000000322749.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000322749.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-19 21:13:16',
#   'flickr_url': 'http://farm5.staticflickr.com/4093/4915514425_9e5338fb29_z.jpg',
#   'id': 322749},
#  {'license': 3,
#   'file_name': '000000318299.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000318299.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 17:58:55',
#   'flickr_url': 'http://farm4.staticflickr.com/3781/9068155095_7ac8f8ef74_z.jpg',
#   'id': 318299},
#  {'license': 3,
#   'file_name': '000000025290.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000025290.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-14 20:23:19',
#   'flickr_url': 'http://farm1.staticflickr.com/33/55074253_6d399d3c3d_z.jpg',
#   'id': 25290},
#  {'license': 3,
#   'file_name': '000000020276.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000020276.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-21 00:30:10',
#   'flickr_url': 'http://farm5.staticflickr.com/4132/5048683260_145c095b6f_z.jpg',
#   'id': 20276},
#  {'license': 3,
#   'file_name': '000000209692.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000209692.jpg',
#   'height': 639,
#   'width': 640,
#   'date_captured': '2013-11-17 21:22:03',
#   'flickr_url': 'http://farm8.staticflickr.com/7070/6860117931_d6644023c8_z.jpg',
#   'id': 209692},
#  {'license': 1,
#   'file_name': '000000437607.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000437607.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 05:12:15',
#   'flickr_url': 'http://farm9.staticflickr.com/8380/8584860106_3e46b40ddd_z.jpg',
#   'id': 437607},
#  {'license': 3,
#   'file_name': '000000116389.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000116389.jpg',
#   'height': 512,
#   'width': 528,
#   'date_captured': '2013-11-19 23:14:50',
#   'flickr_url': 'http://farm6.staticflickr.com/5087/5298947271_b75e437cb9_z.jpg',
#   'id': 116389},
#  {'license': 2,
#   'file_name': '000000347238.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000347238.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-18 04:48:20',
#   'flickr_url': 'http://farm9.staticflickr.com/8251/8488012045_14868368e0_z.jpg',
#   'id': 347238},
#  {'license': 1,
#   'file_name': '000000129801.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000129801.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-16 21:44:41',
#   'flickr_url': 'http://farm4.staticflickr.com/3783/8997098613_bf3753d72f_z.jpg',
#   'id': 129801},
#  {'license': 1,
#   'file_name': '000000010909.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000010909.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-14 17:54:02',
#   'flickr_url': 'http://farm1.staticflickr.com/105/313397098_f7c15a66f0_z.jpg',
#   'id': 10909},
#  {'license': 7,
#   'file_name': '000000563376.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000563376.jpg',
#   'height': 506,
#   'width': 640,
#   'date_captured': '2013-11-14 19:41:49',
#   'flickr_url': 'http://farm9.staticflickr.com/8097/8565940263_8be2f73301_z.jpg',
#   'id': 563376},
#  {'license': 1,
#   'file_name': '000000169612.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000169612.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-20 21:49:24',
#   'flickr_url': 'http://farm3.staticflickr.com/2059/1554385558_a78b6a0b83_z.jpg',
#   'id': 169612},
#  {'license': 1,
#   'file_name': '000000368686.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000368686.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-16 13:12:11',
#   'flickr_url': 'http://farm4.staticflickr.com/3080/2855027388_0eb27b5180_z.jpg',
#   'id': 368686},
#  {'license': 1,
#   'file_name': '000000062839.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000062839.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-15 11:55:29',
#   'flickr_url': 'http://farm2.staticflickr.com/1310/5142617970_0e35f61709_z.jpg',
#   'id': 62839},
#  {'license': 1,
#   'file_name': '000000153290.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000153290.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-17 00:56:01',
#   'flickr_url': 'http://farm4.staticflickr.com/3262/2656224689_8fcbf08cef_z.jpg',
#   'id': 153290},
#  {'license': 1,
#   'file_name': '000000326499.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000326499.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-20 01:29:05',
#   'flickr_url': 'http://farm7.staticflickr.com/6106/6271359529_df853ff9d1_z.jpg',
#   'id': 326499},
#  {'license': 1,
#   'file_name': '000000199715.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000199715.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 14:46:43',
#   'flickr_url': 'http://farm7.staticflickr.com/6054/5902964810_8c801e1ba9_z.jpg',
#   'id': 199715},
#  {'license': 1,
#   'file_name': '000000239120.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000239120.jpg',
#   'height': 640,
#   'width': 428,
#   'date_captured': '2013-11-24 05:47:16',
#   'flickr_url': 'http://farm7.staticflickr.com/6003/5971313316_66b98f304b_z.jpg',
#   'id': 239120},
#  {'license': 3,
#   'file_name': '000000559565.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000559565.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-24 19:21:58',
#   'flickr_url': 'http://farm3.staticflickr.com/2314/4513201172_139c6f95d9_z.jpg',
#   'id': 559565},
#  {'license': 2,
#   'file_name': '000000488060.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000488060.jpg',
#   'height': 500,
#   'width': 419,
#   'date_captured': '2013-11-15 13:16:27',
#   'flickr_url': 'http://farm3.staticflickr.com/2593/4176455998_633e5a8dc1_z.jpg',
#   'id': 488060},
#  {'license': 3,
#   'file_name': '000000125586.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000125586.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-18 19:08:37',
#   'flickr_url': 'http://farm4.staticflickr.com/3515/4026915360_c930732188_z.jpg',
#   'id': 125586},
#  {'license': 1,
#   'file_name': '000000511506.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000511506.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-14 11:55:54',
#   'flickr_url': 'http://farm1.staticflickr.com/17/21634369_5ce3ebdcb2_z.jpg',
#   'id': 511506},
#  {'license': 1,
#   'file_name': '000000552990.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000552990.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-15 22:58:18',
#   'flickr_url': 'http://farm4.staticflickr.com/3083/2477419353_26a548003c_z.jpg',
#   'id': 552990},
#  {'license': 2,
#   'file_name': '000000239254.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000239254.jpg',
#   'height': 335,
#   'width': 500,
#   'date_captured': '2013-11-18 21:28:56',
#   'flickr_url': 'http://farm1.staticflickr.com/199/496978754_41355e88c9_z.jpg',
#   'id': 239254},
#  {'license': 1,
#   'file_name': '000000070133.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000070133.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-24 02:18:56',
#   'flickr_url': 'http://farm4.staticflickr.com/3309/3263237188_48cc597bfa_z.jpg',
#   'id': 70133},
#  {'license': 6,
#   'file_name': '000000093599.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000093599.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-19 21:01:21',
#   'flickr_url': 'http://farm5.staticflickr.com/4109/5036182679_b937a64a0a_z.jpg',
#   'id': 93599},
#  {'license': 5,
#   'file_name': '000000006107.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000006107.jpg',
#   'height': 438,
#   'width': 640,
#   'date_captured': '2013-11-19 20:37:56',
#   'flickr_url': 'http://farm4.staticflickr.com/3072/2999174370_875ff8f849_z.jpg',
#   'id': 6107},
#  {'license': 3,
#   'file_name': '000000076768.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000076768.jpg',
#   'height': 640,
#   'width': 473,
#   'date_captured': '2013-11-17 09:11:09',
#   'flickr_url': 'http://farm6.staticflickr.com/5445/9051151092_2e21ace2b4_z.jpg',
#   'id': 76768},
#  {'license': 3,
#   'file_name': '000000295267.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000295267.jpg',
#   'height': 478,
#   'width': 640,
#   'date_captured': '2013-11-15 04:13:52',
#   'flickr_url': 'http://farm7.staticflickr.com/6083/6045304429_df10bb367e_z.jpg',
#   'id': 295267},
#  {'license': 3,
#   'file_name': '000000314983.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000314983.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-24 12:21:13',
#   'flickr_url': 'http://farm1.staticflickr.com/87/254361000_f8824289e1_z.jpg',
#   'id': 314983},
#  {'license': 1,
#   'file_name': '000000205934.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000205934.jpg',
#   'height': 640,
#   'width': 462,
#   'date_captured': '2013-11-24 19:51:27',
#   'flickr_url': 'http://farm3.staticflickr.com/2074/2303959698_4777e41f92_z.jpg',
#   'id': 205934},
#  {'license': 5,
#   'file_name': '000000255076.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000255076.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-19 18:47:33',
#   'flickr_url': 'http://farm8.staticflickr.com/7070/6800309246_3195e87c92_z.jpg',
#   'id': 255076},
#  {'license': 6,
#   'file_name': '000000059416.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000059416.jpg',
#   'height': 376,
#   'width': 640,
#   'date_captured': '2013-11-17 10:53:50',
#   'flickr_url': 'http://farm9.staticflickr.com/8389/8627274553_dbecabdaf4_z.jpg',
#   'id': 59416},
#  {'license': 5,
#   'file_name': '000000319346.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000319346.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 20:17:17',
#   'flickr_url': 'http://farm9.staticflickr.com/8538/8709798822_0d59ffdbdf_z.jpg',
#   'id': 319346},
#  {'license': 4,
#   'file_name': '000000133619.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000133619.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-17 21:50:18',
#   'flickr_url': 'http://farm8.staticflickr.com/7155/6429061599_e265817981_z.jpg',
#   'id': 133619},
#  {'license': 4,
#   'file_name': '000000375590.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000375590.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-21 00:02:51',
#   'flickr_url': 'http://farm6.staticflickr.com/5511/10283468455_3b3b36c7d4_z.jpg',
#   'id': 375590},
#  {'license': 2,
#   'file_name': '000000134846.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000134846.jpg',
#   'height': 383,
#   'width': 640,
#   'date_captured': '2013-11-18 12:05:43',
#   'flickr_url': 'http://farm6.staticflickr.com/5026/5801898247_5e4fcd9098_z.jpg',
#   'id': 134846},
#  {'license': 1,
#   'file_name': '000000524041.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000524041.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-21 20:17:44',
#   'flickr_url': 'http://farm4.staticflickr.com/3133/2865564151_158c4e6587_z.jpg',
#   'id': 524041},
#  {'license': 1,
#   'file_name': '000000120247.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000120247.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-15 13:27:15',
#   'flickr_url': 'http://farm6.staticflickr.com/5018/5543684899_ca6dc57ae4_z.jpg',
#   'id': 120247},
#  {'license': 1,
#   'file_name': '000000125263.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000125263.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 01:56:49',
#   'flickr_url': 'http://farm1.staticflickr.com/141/403776782_51462775e1_z.jpg',
#   'id': 125263},
#  {'license': 2,
#   'file_name': '000000507910.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000507910.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-24 04:13:38',
#   'flickr_url': 'http://farm8.staticflickr.com/7006/6565600981_cf981dd37c_z.jpg',
#   'id': 507910},
#  {'license': 3,
#   'file_name': '000000014271.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000014271.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-16 17:49:48',
#   'flickr_url': 'http://farm7.staticflickr.com/6183/6050931846_4b55ef0776_z.jpg',
#   'id': 14271},
#  {'license': 2,
#   'file_name': '000000124606.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000124606.jpg',
#   'height': 640,
#   'width': 634,
#   'date_captured': '2013-11-19 00:08:54',
#   'flickr_url': 'http://farm8.staticflickr.com/7389/10109547446_4f2a972eee_z.jpg',
#   'id': 124606},
#  {'license': 4,
#   'file_name': '000000260415.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000260415.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-19 19:17:00',
#   'flickr_url': 'http://farm6.staticflickr.com/5077/5905209862_d18ccb0efa_z.jpg',
#   'id': 260415},
#  {'license': 1,
#   'file_name': '000000043289.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000043289.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-17 22:01:43',
#   'flickr_url': 'http://farm6.staticflickr.com/5234/5868058785_0009042cd7_z.jpg',
#   'id': 43289},
#  {'license': 2,
#   'file_name': '000000575349.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000575349.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-20 16:35:10',
#   'flickr_url': 'http://farm9.staticflickr.com/8033/7983019848_134a73ec19_z.jpg',
#   'id': 575349},
#  {'license': 4,
#   'file_name': '000000261068.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000261068.jpg',
#   'height': 429,
#   'width': 640,
#   'date_captured': '2013-11-16 22:08:01',
#   'flickr_url': 'http://farm8.staticflickr.com/7033/6569082533_71dd04493f_z.jpg',
#   'id': 261068},
#  {'license': 4,
#   'file_name': '000000439072.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000439072.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-22 21:46:54',
#   'flickr_url': 'http://farm4.staticflickr.com/3775/9396887523_753ba5c765_z.jpg',
#   'id': 439072},
#  {'license': 1,
#   'file_name': '000000489622.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000489622.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-24 03:17:50',
#   'flickr_url': 'http://farm9.staticflickr.com/8027/7586345672_1f5733a05f_z.jpg',
#   'id': 489622},
#  {'license': 4,
#   'file_name': '000000336688.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000336688.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-21 20:20:08',
#   'flickr_url': 'http://farm9.staticflickr.com/8497/8308032552_47d41d6ce7_z.jpg',
#   'id': 336688},
#  {'license': 4,
#   'file_name': '000000342380.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000342380.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 19:30:46',
#   'flickr_url': 'http://farm8.staticflickr.com/7226/7183463507_a8cc3ee089_z.jpg',
#   'id': 342380},
#  {'license': 3,
#   'file_name': '000000296153.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000296153.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-24 00:52:39',
#   'flickr_url': 'http://farm3.staticflickr.com/2031/2288790547_45b5fb8bbb_z.jpg',
#   'id': 296153},
#  {'license': 4,
#   'file_name': '000000532211.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000532211.jpg',
#   'height': 332,
#   'width': 500,
#   'date_captured': '2013-11-20 06:33:11',
#   'flickr_url': 'http://farm3.staticflickr.com/2675/4050524525_e9ba2cbfdd_z.jpg',
#   'id': 532211},
#  {'license': 4,
#   'file_name': '000000461002.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000461002.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-22 19:24:07',
#   'flickr_url': 'http://farm2.staticflickr.com/1016/537599964_610056d33f_z.jpg',
#   'id': 461002},
#  {'license': 3,
#   'file_name': '000000198653.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000198653.jpg',
#   'height': 406,
#   'width': 640,
#   'date_captured': '2013-11-14 19:20:26',
#   'flickr_url': 'http://farm6.staticflickr.com/5187/5641728818_4baa5a8128_z.jpg',
#   'id': 198653},
#  {'license': 3,
#   'file_name': '000000245559.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000245559.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 07:05:35',
#   'flickr_url': 'http://farm8.staticflickr.com/7282/9672448907_8c984d4728_z.jpg',
#   'id': 245559},
#  {'license': 6,
#   'file_name': '000000189853.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000189853.jpg',
#   'height': 479,
#   'width': 640,
#   'date_captured': '2013-11-16 14:35:54',
#   'flickr_url': 'http://farm3.staticflickr.com/2040/5714249581_c9b7ee5f22_z.jpg',
#   'id': 189853},
#  {'license': 3,
#   'file_name': '000000090793.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000090793.jpg',
#   'height': 363,
#   'width': 640,
#   'date_captured': '2013-11-22 10:44:45',
#   'flickr_url': 'http://farm6.staticflickr.com/5321/9099336460_6150a8f15d_z.jpg',
#   'id': 90793},
#  {'license': 4,
#   'file_name': '000000555365.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000555365.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-16 17:30:17',
#   'flickr_url': 'http://farm4.staticflickr.com/3281/2657005234_85e1ec801e_z.jpg',
#   'id': 555365},
#  {'license': 4,
#   'file_name': '000000377017.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000377017.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-24 07:38:00',
#   'flickr_url': 'http://farm1.staticflickr.com/149/351828095_8c3ea7c526_z.jpg',
#   'id': 377017},
#  {'license': 6,
#   'file_name': '000000133284.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000133284.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-17 07:27:25',
#   'flickr_url': 'http://farm1.staticflickr.com/29/54464101_fec088195c_z.jpg',
#   'id': 133284},
#  {'license': 3,
#   'file_name': '000000226805.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000226805.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-21 21:47:45',
#   'flickr_url': 'http://farm9.staticflickr.com/8310/8052628966_a18bff18bd_z.jpg',
#   'id': 226805},
#  {'license': 1,
#   'file_name': '000000126563.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000126563.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 20:02:44',
#   'flickr_url': 'http://farm6.staticflickr.com/5504/9284305036_e3d72e3af3_z.jpg',
#   'id': 126563},
#  {'license': 1,
#   'file_name': '000000508354.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000508354.jpg',
#   'height': 594,
#   'width': 640,
#   'date_captured': '2013-11-21 05:04:21',
#   'flickr_url': 'http://farm5.staticflickr.com/4085/5067103380_648488fa97_z.jpg',
#   'id': 508354},
#  {'license': 1,
#   'file_name': '000000486503.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000486503.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-22 22:48:15',
#   'flickr_url': 'http://farm4.staticflickr.com/3133/2639853160_8d67c0d35c_z.jpg',
#   'id': 486503},
#  {'license': 2,
#   'file_name': '000000553934.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000553934.jpg',
#   'height': 443,
#   'width': 640,
#   'date_captured': '2013-11-24 20:44:15',
#   'flickr_url': 'http://farm3.staticflickr.com/2559/5725929989_8888c91df3_z.jpg',
#   'id': 553934},
#  {'license': 3,
#   'file_name': '000000252277.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000252277.jpg',
#   'height': 394,
#   'width': 640,
#   'date_captured': '2013-11-24 00:53:10',
#   'flickr_url': 'http://farm4.staticflickr.com/3479/3186200071_c299b046d9_z.jpg',
#   'id': 252277},
#  {'license': 4,
#   'file_name': '000000548858.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000548858.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-24 10:24:16',
#   'flickr_url': 'http://farm3.staticflickr.com/2631/5740102701_9e87d6496a_z.jpg',
#   'id': 548858},
#  {'license': 5,
#   'file_name': '000000252373.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000252373.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 19:08:46',
#   'flickr_url': 'http://farm8.staticflickr.com/7021/6420121899_9f11ded9f8_z.jpg',
#   'id': 252373},
#  {'license': 3,
#   'file_name': '000000318469.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000318469.jpg',
#   'height': 512,
#   'width': 640,
#   'date_captured': '2013-11-16 21:31:39',
#   'flickr_url': 'http://farm8.staticflickr.com/7193/6973941664_7ee2358df5_z.jpg',
#   'id': 318469},
#  {'license': 1,
#   'file_name': '000000483494.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000483494.jpg',
#   'height': 500,
#   'width': 352,
#   'date_captured': '2013-11-18 11:34:32',
#   'flickr_url': 'http://farm1.staticflickr.com/192/499896761_be5394d847_z.jpg',
#   'id': 483494},
#  {'license': 6,
#   'file_name': '000000478553.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000478553.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-18 18:48:49',
#   'flickr_url': 'http://farm5.staticflickr.com/4119/4797662069_fdba2f2c8f_z.jpg',
#   'id': 478553},
#  {'license': 2,
#   'file_name': '000000281868.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000281868.jpg',
#   'height': 500,
#   'width': 374,
#   'date_captured': '2013-11-15 02:24:53',
#   'flickr_url': 'http://farm5.staticflickr.com/4040/4304587428_914d0e0c96_z.jpg',
#   'id': 281868},
#  {'license': 4,
#   'file_name': '000000145945.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000145945.jpg',
#   'height': 361,
#   'width': 640,
#   'date_captured': '2013-11-16 22:13:40',
#   'flickr_url': 'http://farm8.staticflickr.com/7294/8732404809_de442c8e96_z.jpg',
#   'id': 145945},
#  {'license': 2,
#   'file_name': '000000041773.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000041773.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 03:02:14',
#   'flickr_url': 'http://farm5.staticflickr.com/4030/4623906560_212407aa92_z.jpg',
#   'id': 41773},
#  {'license': 1,
#   'file_name': '000000527064.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000527064.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-21 05:24:45',
#   'flickr_url': 'http://farm5.staticflickr.com/4094/4849921082_b3966f18e3_z.jpg',
#   'id': 527064},
#  {'license': 1,
#   'file_name': '000000212566.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000212566.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-16 19:34:07',
#   'flickr_url': 'http://farm4.staticflickr.com/3672/8983221753_d5fdf788de_z.jpg',
#   'id': 212566},
#  {'license': 2,
#   'file_name': '000000571448.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000571448.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-24 21:51:01',
#   'flickr_url': 'http://farm1.staticflickr.com/5/5405315_76cde61eab_z.jpg',
#   'id': 571448},
#  {'license': 5,
#   'file_name': '000000062880.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000062880.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 16:41:46',
#   'flickr_url': 'http://farm9.staticflickr.com/8109/8607284715_688d12bd72_z.jpg',
#   'id': 62880},
#  {'license': 2,
#   'file_name': '000000205367.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000205367.jpg',
#   'height': 433,
#   'width': 640,
#   'date_captured': '2013-11-23 04:46:36',
#   'flickr_url': 'http://farm3.staticflickr.com/2295/1802940966_e3ee16a179_z.jpg',
#   'id': 205367},
#  {'license': 1,
#   'file_name': '000000042415.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000042415.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 08:04:50',
#   'flickr_url': 'http://farm3.staticflickr.com/2851/9378220771_917f34bda6_z.jpg',
#   'id': 42415},
#  {'license': 1,
#   'file_name': '000000325472.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000325472.jpg',
#   'height': 439,
#   'width': 640,
#   'date_captured': '2013-11-18 23:03:49',
#   'flickr_url': 'http://farm7.staticflickr.com/6146/5920529177_33daca3d9f_z.jpg',
#   'id': 325472},
#  {'license': 4,
#   'file_name': '000000145335.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000145335.jpg',
#   'height': 457,
#   'width': 640,
#   'date_captured': '2013-11-20 09:11:24',
#   'flickr_url': 'http://farm8.staticflickr.com/7008/6774596139_437ce9495f_z.jpg',
#   'id': 145335},
#  {'license': 1,
#   'file_name': '000000484288.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000484288.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-24 08:24:10',
#   'flickr_url': 'http://farm5.staticflickr.com/4034/4360929393_7fd7d013bc_z.jpg',
#   'id': 484288},
#  {'license': 4,
#   'file_name': '000000526599.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000526599.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-21 20:16:48',
#   'flickr_url': 'http://farm7.staticflickr.com/6035/6294041625_191153e88b_z.jpg',
#   'id': 526599},
#  {'license': 4,
#   'file_name': '000000021644.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000021644.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 22:49:16',
#   'flickr_url': 'http://farm9.staticflickr.com/8243/8622196262_8e450eb9ff_z.jpg',
#   'id': 21644},
#  {'license': 3,
#   'file_name': '000000056201.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000056201.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-19 22:45:11',
#   'flickr_url': 'http://farm2.staticflickr.com/1091/5156378817_7662ef3771_z.jpg',
#   'id': 56201},
#  {'license': 1,
#   'file_name': '000000070353.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000070353.jpg',
#   'height': 472,
#   'width': 640,
#   'date_captured': '2013-11-18 06:08:27',
#   'flickr_url': 'http://farm4.staticflickr.com/3279/2985312811_4d35aa030c_z.jpg',
#   'id': 70353},
#  {'license': 1,
#   'file_name': '000000313340.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000313340.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-22 00:33:04',
#   'flickr_url': 'http://farm1.staticflickr.com/39/77064601_b3fd2f5fa7_z.jpg',
#   'id': 313340},
#  {'license': 3,
#   'file_name': '000000091886.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000091886.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-23 00:28:08',
#   'flickr_url': 'http://farm9.staticflickr.com/8542/8637362986_aa269843d4_z.jpg',
#   'id': 91886},
#  {'license': 4,
#   'file_name': '000000570694.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000570694.jpg',
#   'height': 335,
#   'width': 500,
#   'date_captured': '2013-11-20 06:10:52',
#   'flickr_url': 'http://farm3.staticflickr.com/2453/3832512169_e26dcf75d5_z.jpg',
#   'id': 570694},
#  {'license': 1,
#   'file_name': '000000349931.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000349931.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 17:45:07',
#   'flickr_url': 'http://farm6.staticflickr.com/5487/9250510895_b5fa486205_z.jpg',
#   'id': 349931},
#  {'license': 5,
#   'file_name': '000000430391.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000430391.jpg',
#   'height': 361,
#   'width': 640,
#   'date_captured': '2013-11-18 03:15:39',
#   'flickr_url': 'http://farm3.staticflickr.com/2722/4269073113_918a832df1_z.jpg',
#   'id': 430391},
#  {'license': 1,
#   'file_name': '000000171649.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000171649.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 02:29:25',
#   'flickr_url': 'http://farm5.staticflickr.com/4058/5150231329_39c21f2ce5_z.jpg',
#   'id': 171649},
#  {'license': 2,
#   'file_name': '000000224928.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000224928.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-22 15:46:27',
#   'flickr_url': 'http://farm6.staticflickr.com/5099/5477469711_66dda6739e_z.jpg',
#   'id': 224928},
#  {'license': 4,
#   'file_name': '000000074820.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000074820.jpg',
#   'height': 640,
#   'width': 548,
#   'date_captured': '2013-11-19 20:25:25',
#   'flickr_url': 'http://farm9.staticflickr.com/8342/8204644418_40c45dca45_z.jpg',
#   'id': 74820},
#  {'license': 6,
#   'file_name': '000000514230.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000514230.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-16 13:29:09',
#   'flickr_url': 'http://farm1.staticflickr.com/70/155273802_4143b8dfd7_z.jpg',
#   'id': 514230},
#  {'license': 4,
#   'file_name': '000000396412.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000396412.jpg',
#   'height': 640,
#   'width': 418,
#   'date_captured': '2013-11-15 17:04:48',
#   'flickr_url': 'http://farm2.staticflickr.com/1424/5130248266_b197abbd06_z.jpg',
#   'id': 396412},
#  {'license': 1,
#   'file_name': '000000151609.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000151609.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-17 21:34:55',
#   'flickr_url': 'http://farm1.staticflickr.com/102/305877545_4b96cf5fea_z.jpg',
#   'id': 151609},
#  {'license': 4,
#   'file_name': '000000188927.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000188927.jpg',
#   'height': 399,
#   'width': 640,
#   'date_captured': '2013-11-16 15:26:24',
#   'flickr_url': 'http://farm8.staticflickr.com/7226/6982824652_dbd786ef76_z.jpg',
#   'id': 188927},
#  {'license': 2,
#   'file_name': '000000045554.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000045554.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-19 17:57:57',
#   'flickr_url': 'http://farm3.staticflickr.com/2351/2649901934_cc2f773357_z.jpg',
#   'id': 45554},
#  {'license': 1,
#   'file_name': '000000525152.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000525152.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-16 13:41:17',
#   'flickr_url': 'http://farm8.staticflickr.com/7147/6799462135_69160cdaa3_z.jpg',
#   'id': 525152},
#  {'license': 3,
#   'file_name': '000000270852.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000270852.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-19 22:21:15',
#   'flickr_url': 'http://farm6.staticflickr.com/5260/5528408819_8dbdc4629c_z.jpg',
#   'id': 270852},
#  {'license': 1,
#   'file_name': '000000178131.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000178131.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 17:36:10',
#   'flickr_url': 'http://farm3.staticflickr.com/2637/3970142586_530e476f06_z.jpg',
#   'id': 178131},
#  {'license': 4,
#   'file_name': '000000167968.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000167968.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-15 14:25:27',
#   'flickr_url': 'http://farm9.staticflickr.com/8078/8347276289_20a1929ee4_z.jpg',
#   'id': 167968},
#  {'license': 4,
#   'file_name': '000000048784.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000048784.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 21:36:19',
#   'flickr_url': 'http://farm8.staticflickr.com/7436/9122131108_a5c7fe6a0a_z.jpg',
#   'id': 48784},
#  {'license': 1,
#   'file_name': '000000054479.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000054479.jpg',
#   'height': 481,
#   'width': 640,
#   'date_captured': '2013-11-22 22:52:21',
#   'flickr_url': 'http://farm4.staticflickr.com/3039/2490516077_9045cd2a18_z.jpg',
#   'id': 54479},
#  {'license': 3,
#   'file_name': '000000412136.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000412136.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-20 14:11:12',
#   'flickr_url': 'http://farm9.staticflickr.com/8383/8620237611_d5bc494dd9_z.jpg',
#   'id': 412136},
#  {'license': 2,
#   'file_name': '000000062613.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000062613.jpg',
#   'height': 600,
#   'width': 400,
#   'date_captured': '2013-11-21 04:58:16',
#   'flickr_url': 'http://farm5.staticflickr.com/4084/5173386867_85baef9416_z.jpg',
#   'id': 62613},
#  {'license': 6,
#   'file_name': '000000578671.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000578671.jpg',
#   'height': 424,
#   'width': 640,
#   'date_captured': '2013-11-16 16:39:52',
#   'flickr_url': 'http://farm3.staticflickr.com/2894/9255733537_b24ee4cafa_z.jpg',
#   'id': 578671},
#  {'license': 3,
#   'file_name': '000000451014.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000451014.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-16 23:19:36',
#   'flickr_url': 'http://farm4.staticflickr.com/3127/2719957871_5b7c7cc36e_z.jpg',
#   'id': 451014},
#  {'license': 5,
#   'file_name': '000000167330.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000167330.jpg',
#   'height': 500,
#   'width': 333,
#   'date_captured': '2013-11-17 00:48:53',
#   'flickr_url': 'http://farm3.staticflickr.com/2465/3705215978_5862aebfd3_z.jpg',
#   'id': 167330},
#  {'license': 2,
#   'file_name': '000000541859.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000541859.jpg',
#   'height': 618,
#   'width': 640,
#   'date_captured': '2013-11-18 15:55:51',
#   'flickr_url': 'http://farm3.staticflickr.com/2539/4084324320_798a59a4c4_z.jpg',
#   'id': 541859},
#  {'license': 2,
#   'file_name': '000000173598.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000173598.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 21:24:45',
#   'flickr_url': 'http://farm2.staticflickr.com/1153/872564656_70404bea04_z.jpg',
#   'id': 173598},
#  {'license': 3,
#   'file_name': '000000564978.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000564978.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-15 23:17:09',
#   'flickr_url': 'http://farm4.staticflickr.com/3177/3035240500_0f39cd7267_z.jpg',
#   'id': 564978},
#  {'license': 4,
#   'file_name': '000000396006.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000396006.jpg',
#   'height': 304,
#   'width': 640,
#   'date_captured': '2013-11-19 18:44:35',
#   'flickr_url': 'http://farm3.staticflickr.com/2722/4201737702_fbe8337f46_z.jpg',
#   'id': 396006},
#  {'license': 5,
#   'file_name': '000000106244.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000106244.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 16:09:59',
#   'flickr_url': 'http://farm2.staticflickr.com/1254/1058880208_a76cc93492_z.jpg',
#   'id': 106244},
#  {'license': 1,
#   'file_name': '000000205911.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000205911.jpg',
#   'height': 457,
#   'width': 640,
#   'date_captured': '2013-11-19 22:49:08',
#   'flickr_url': 'http://farm6.staticflickr.com/5260/5436883000_e84da3d7aa_z.jpg',
#   'id': 205911},
#  {'license': 3,
#   'file_name': '000000513099.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000513099.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-16 22:27:52',
#   'flickr_url': 'http://farm3.staticflickr.com/2435/3698360709_ae64c61cca_z.jpg',
#   'id': 513099},
#  {'license': 4,
#   'file_name': '000000497801.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000497801.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 21:24:54',
#   'flickr_url': 'http://farm9.staticflickr.com/8284/7519190016_622432cfc0_z.jpg',
#   'id': 497801},
#  {'license': 5,
#   'file_name': '000000357356.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000357356.jpg',
#   'height': 500,
#   'width': 332,
#   'date_captured': '2013-11-18 17:38:19',
#   'flickr_url': 'http://farm2.staticflickr.com/1437/1197425992_85b8393b8e_z.jpg',
#   'id': 357356},
#  {'license': 3,
#   'file_name': '000000568179.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000568179.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-19 22:28:37',
#   'flickr_url': 'http://farm5.staticflickr.com/4067/4673154240_49173b0c87_z.jpg',
#   'id': 568179},
#  {'license': 5,
#   'file_name': '000000386119.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000386119.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-18 00:28:51',
#   'flickr_url': 'http://farm4.staticflickr.com/3799/9432503527_ceffd99dd0_z.jpg',
#   'id': 386119},
#  {'license': 6,
#   'file_name': '000000263724.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000263724.jpg',
#   'height': 434,
#   'width': 640,
#   'date_captured': '2013-11-18 07:21:32',
#   'flickr_url': 'http://farm6.staticflickr.com/5442/9301982210_97d5c6e70e_z.jpg',
#   'id': 263724},
#  {'license': 4,
#   'file_name': '000000000459.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000000459.jpg',
#   'height': 640,
#   'width': 516,
#   'date_captured': '2013-11-18 01:22:48',
#   'flickr_url': 'http://farm4.staticflickr.com/3051/4649315302_7f9d077ecf_z.jpg',
#   'id': 459},
#  {'license': 4,
#   'file_name': '000000145452.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000145452.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-19 23:51:51',
#   'flickr_url': 'http://farm3.staticflickr.com/2304/4513488696_40085c7d8e_z.jpg',
#   'id': 145452},
#  {'license': 3,
#   'file_name': '000000038840.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000038840.jpg',
#   'height': 478,
#   'width': 640,
#   'date_captured': '2013-11-19 18:10:20',
#   'flickr_url': 'http://farm3.staticflickr.com/2480/5714790197_98e162bc98_z.jpg',
#   'id': 38840},
#  {'license': 3,
#   'file_name': '000000505619.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000505619.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-24 23:27:44',
#   'flickr_url': 'http://farm8.staticflickr.com/7302/8733767055_2bdbac4588_z.jpg',
#   'id': 505619},
#  {'license': 6,
#   'file_name': '000000468393.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000468393.jpg',
#   'height': 623,
#   'width': 640,
#   'date_captured': '2013-11-21 02:16:02',
#   'flickr_url': 'http://farm4.staticflickr.com/3680/9258503788_28c667052d_z.jpg',
#   'id': 468393},
#  {'license': 4,
#   'file_name': '000000004880.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000004880.jpg',
#   'height': 640,
#   'width': 424,
#   'date_captured': '2013-11-24 15:28:26',
#   'flickr_url': 'http://farm9.staticflickr.com/8177/8009394217_2aa05bb5b6_z.jpg',
#   'id': 4880},
#  {'license': 4,
#   'file_name': '000000233383.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000233383.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-18 00:09:40',
#   'flickr_url': 'http://farm4.staticflickr.com/3171/5745912720_94dd337187_z.jpg',
#   'id': 233383},
#  {'license': 1,
#   'file_name': '000000156776.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000156776.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-24 12:26:12',
#   'flickr_url': 'http://farm1.staticflickr.com/55/116535229_88c287e6a8_z.jpg',
#   'id': 156776},
#  {'license': 5,
#   'file_name': '000000019766.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000019766.jpg',
#   'height': 387,
#   'width': 640,
#   'date_captured': '2013-11-19 21:53:17',
#   'flickr_url': 'http://farm6.staticflickr.com/5180/5455469661_55f2f22dde_z.jpg',
#   'id': 19766},
#  {'license': 4,
#   'file_name': '000000090245.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000090245.jpg',
#   'height': 477,
#   'width': 640,
#   'date_captured': '2013-11-18 15:16:30',
#   'flickr_url': 'http://farm1.staticflickr.com/154/426185290_0036d31973_z.jpg',
#   'id': 90245},
#  {'license': 3,
#   'file_name': '000000539147.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000539147.jpg',
#   'height': 416,
#   'width': 500,
#   'date_captured': '2013-11-20 10:31:34',
#   'flickr_url': 'http://farm4.staticflickr.com/3140/2961001505_dcbacb5891_z.jpg',
#   'id': 539147},
#  {'license': 3,
#   'file_name': '000000453862.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000453862.jpg',
#   'height': 500,
#   'width': 333,
#   'date_captured': '2013-11-24 09:22:16',
#   'flickr_url': 'http://farm1.staticflickr.com/188/419844580_a7a5003843_z.jpg',
#   'id': 453862},
#  {'license': 1,
#   'file_name': '000000049369.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000049369.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 09:19:11',
#   'flickr_url': 'http://farm5.staticflickr.com/4123/4778600560_b5a62110c4_z.jpg',
#   'id': 49369},
#  {'license': 3,
#   'file_name': '000000569703.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000569703.jpg',
#   'height': 334,
#   'width': 500,
#   'date_captured': '2013-11-18 02:48:53',
#   'flickr_url': 'http://farm1.staticflickr.com/157/366305089_c5daaec9c3_z.jpg',
#   'id': 569703},
#  {'license': 3,
#   'file_name': '000000574059.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000574059.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 22:02:58',
#   'flickr_url': 'http://farm1.staticflickr.com/114/251655469_0294fb1db5_z.jpg',
#   'id': 574059},
#  {'license': 4,
#   'file_name': '000000575908.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000575908.jpg',
#   'height': 425,
#   'width': 640,
#   'date_captured': '2013-11-20 13:46:24',
#   'flickr_url': 'http://farm5.staticflickr.com/4092/5063888144_b8fa98b88e_z.jpg',
#   'id': 575908},
#  {'license': 3,
#   'file_name': '000000011619.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000011619.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-24 09:38:34',
#   'flickr_url': 'http://farm1.staticflickr.com/34/120036011_5a956b5314_z.jpg',
#   'id': 11619},
#  {'license': 1,
#   'file_name': '000000337304.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000337304.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-18 06:51:00',
#   'flickr_url': 'http://farm7.staticflickr.com/6090/6208036783_79d37d46f6_z.jpg',
#   'id': 337304},
#  {'license': 2,
#   'file_name': '000000361245.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000361245.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-19 21:11:53',
#   'flickr_url': 'http://farm8.staticflickr.com/7200/6934105827_06a53e52be_z.jpg',
#   'id': 361245},
#  {'license': 2,
#   'file_name': '000000425037.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000425037.jpg',
#   'height': 500,
#   'width': 375,
#   'date_captured': '2013-11-24 19:46:12',
#   'flickr_url': 'http://farm4.staticflickr.com/3145/2872017808_1c23821f06_z.jpg',
#   'id': 425037},
#  {'license': 5,
#   'file_name': '000000152499.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000152499.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 07:24:16',
#   'flickr_url': 'http://farm8.staticflickr.com/7144/6615930027_1f4c62741a_z.jpg',
#   'id': 152499},
#  {'license': 5,
#   'file_name': '000000013678.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000013678.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-17 17:00:04',
#   'flickr_url': 'http://farm4.staticflickr.com/3472/3721936296_19367b99b9_z.jpg',
#   'id': 13678},
#  {'license': 6,
#   'file_name': '000000135327.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000135327.jpg',
#   'height': 300,
#   'width': 440,
#   'date_captured': '2013-11-21 03:09:21',
#   'flickr_url': 'http://farm8.staticflickr.com/7027/6468366313_a6c6489b61_z.jpg',
#   'id': 135327},
#  {'license': 3,
#   'file_name': '000000513956.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000513956.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-18 01:34:00',
#   'flickr_url': 'http://farm8.staticflickr.com/7059/7136500841_e6b4c3a5ee_z.jpg',
#   'id': 513956},
#  {'license': 4,
#   'file_name': '000000099222.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000099222.jpg',
#   'height': 375,
#   'width': 500,
#   'date_captured': '2013-11-19 18:31:52',
#   'flickr_url': 'http://farm4.staticflickr.com/3245/2436824577_1c754256cf_z.jpg',
#   'id': 99222},
#  {'license': 4,
#   'file_name': '000000316605.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000316605.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-19 23:28:18',
#   'flickr_url': 'http://farm9.staticflickr.com/8482/8213444682_c7bea1f0b4_z.jpg',
#   'id': 316605},
#  {'license': 1,
#   'file_name': '000000339042.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000339042.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-25 08:13:38',
#   'flickr_url': 'http://farm4.staticflickr.com/3749/9483696876_260a16b0c7_z.jpg',
#   'id': 339042},
#  {'license': 4,
#   'file_name': '000000379914.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000379914.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-21 02:42:50',
#   'flickr_url': 'http://farm9.staticflickr.com/8160/6957190352_929fb42b36_z.jpg',
#   'id': 379914},
#  {'license': 3,
#   'file_name': '000000476647.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000476647.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-22 17:37:00',
#   'flickr_url': 'http://farm4.staticflickr.com/3309/3416341937_66704ce311_z.jpg',
#   'id': 476647},
#  {'license': 1,
#   'file_name': '000000071217.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000071217.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-17 08:56:03',
#   'flickr_url': 'http://farm9.staticflickr.com/8510/8573921102_fb3fa986da_z.jpg',
#   'id': 71217},
#  {'license': 3,
#   'file_name': '000000544349.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000544349.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-24 18:47:57',
#   'flickr_url': 'http://farm8.staticflickr.com/7158/6803811555_fef6967e9b_z.jpg',
#   'id': 544349},
#  {'license': 1,
#   'file_name': '000000479314.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000479314.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-21 04:09:19',
#   'flickr_url': 'http://farm7.staticflickr.com/6023/5956174463_3565e2994e_z.jpg',
#   'id': 479314},
#  {'license': 4,
#   'file_name': '000000370819.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000370819.jpg',
#   'height': 333,
#   'width': 500,
#   'date_captured': '2013-11-24 03:40:32',
#   'flickr_url': 'http://farm1.staticflickr.com/152/383936640_34aa57cae8_z.jpg',
#   'id': 370819},
#  {'license': 5,
#   'file_name': '000000524369.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000524369.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-17 01:55:40',
#   'flickr_url': 'http://farm1.staticflickr.com/40/104936944_5917aa34bd_z.jpg',
#   'id': 524369},
#  {'license': 2,
#   'file_name': '000000566765.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000566765.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-15 00:47:38',
#   'flickr_url': 'http://farm1.staticflickr.com/90/253427937_de3c404ee4_z.jpg',
#   'id': 566765},
#  {'license': 1,
#   'file_name': '000000273362.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000273362.jpg',
#   'height': 640,
#   'width': 316,
#   'date_captured': '2013-11-18 18:02:44',
# ...
#   'height': 420,
#   'width': 640,
#   'date_captured': '2013-11-17 10:03:25',
#   'flickr_url': 'http://farm1.staticflickr.com/161/428620156_116517cd93_z.jpg',
#   'id': 452968},
#  {'license': 3,
#   'file_name': '000000404209.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000404209.jpg',
#   'height': 406,
#   'width': 640,
#   'date_captured': '2013-11-20 19:25:49',
#   'flickr_url': 'http://farm4.staticflickr.com/3776/9770500983_b4e4d8fe3d_z.jpg',
#   'id': 404209},
#  {'license': 4,
#   'file_name': '000000376090.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000376090.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-18 17:36:37',
#   'flickr_url': 'http://farm9.staticflickr.com/8439/7796684890_b34929bc8b_z.jpg',
#   'id': 376090},
#  {'license': 1,
#   'file_name': '000000101341.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000101341.jpg',
#   'height': 374,
#   'width': 500,
#   'date_captured': '2013-11-17 02:12:54',
#   'flickr_url': 'http://farm1.staticflickr.com/7/10708797_480878e750_z.jpg',
#   'id': 101341},
#  {'license': 4,
#   'file_name': '000000467130.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000467130.jpg',
#   'height': 491,
#   'width': 640,
#   'date_captured': '2013-11-15 21:39:19',
#   'flickr_url': 'http://farm8.staticflickr.com/7288/9247489789_132c0d534a_z.jpg',
#   'id': 467130},
#  {'license': 4,
#   'file_name': '000000286870.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000286870.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 16:42:55',
#   'flickr_url': 'http://farm4.staticflickr.com/3010/3072146732_3016321b00_z.jpg',
#   'id': 286870},
#  {'license': 3,
#   'file_name': '000000336147.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000336147.jpg',
#   'height': 421,
#   'width': 640,
#   'date_captured': '2013-11-17 04:09:49',
#   'flickr_url': 'http://farm6.staticflickr.com/5498/9909171483_82ffe018b7_z.jpg',
#   'id': 336147},
#  {'license': 1,
#   'file_name': '000000439613.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000439613.jpg',
#   'height': 640,
#   'width': 425,
#   'date_captured': '2013-11-22 22:14:09',
#   'flickr_url': 'http://farm2.staticflickr.com/1235/4607033045_239a559d19_z.jpg',
#   'id': 439613},
#  {'license': 6,
#   'file_name': '000000528275.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000528275.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-18 22:54:08',
#   'flickr_url': 'http://farm8.staticflickr.com/7280/7754165026_a0fd2b9bdf_z.jpg',
#   'id': 528275},
#  {'license': 1,
#   'file_name': '000000179039.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000179039.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-20 12:36:11',
#   'flickr_url': 'http://farm6.staticflickr.com/5107/5665365874_66a8a0f7c1_z.jpg',
#   'id': 179039},
#  {'license': 6,
#   'file_name': '000000045617.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000045617.jpg',
#   'height': 320,
#   'width': 480,
#   'date_captured': '2013-11-18 03:00:36',
#   'flickr_url': 'http://farm7.staticflickr.com/6213/6311664362_9eed6f6580_z.jpg',
#   'id': 45617},
#  {'license': 1,
#   'file_name': '000000212643.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000212643.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-16 02:49:31',
#   'flickr_url': 'http://farm7.staticflickr.com/6064/6043074366_8d96e8fa8e_z.jpg',
#   'id': 212643},
#  {'license': 1,
#   'file_name': '000000499134.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000499134.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-24 00:27:50',
#   'flickr_url': 'http://farm1.staticflickr.com/21/29479484_702f3a0c85_z.jpg',
#   'id': 499134},
#  {'license': 5,
#   'file_name': '000000050161.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000050161.jpg',
#   'height': 428,
#   'width': 640,
#   'date_captured': '2013-11-18 10:44:16',
#   'flickr_url': 'http://farm3.staticflickr.com/2694/4396605539_0462a3dbf1_z.jpg',
#   'id': 50161},
#  {'license': 1,
#   'file_name': '000000234719.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000234719.jpg',
#   'height': 640,
#   'width': 498,
#   'date_captured': '2013-11-17 03:43:33',
#   'flickr_url': 'http://farm3.staticflickr.com/2795/4139583538_43cede34f8_z.jpg',
#   'id': 234719},
#  {'license': 1,
#   'file_name': '000000085731.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000085731.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 20:56:05',
#   'flickr_url': 'http://farm3.staticflickr.com/2137/2434747821_6da47273db_z.jpg',
#   'id': 85731},
#  {'license': 2,
#   'file_name': '000000241528.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000241528.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-15 03:21:59',
#   'flickr_url': 'http://farm8.staticflickr.com/7053/6979663995_8fdccdd2c2_z.jpg',
#   'id': 241528},
#  {'license': 4,
#   'file_name': '000000454382.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000454382.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 18:25:03',
#   'flickr_url': 'http://farm9.staticflickr.com/8255/8637835748_be0f812af0_z.jpg',
#   'id': 454382},
#  {'license': 2,
#   'file_name': '000000215795.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000215795.jpg',
#   'height': 488,
#   'width': 500,
#   'date_captured': '2013-11-18 15:17:57',
#   'flickr_url': 'http://farm4.staticflickr.com/3011/2580017524_444145c634_z.jpg',
#   'id': 215795},
#  {'license': 4,
#   'file_name': '000000274036.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000274036.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 15:07:42',
#   'flickr_url': 'http://farm2.staticflickr.com/1006/707885072_07eeca17bd_z.jpg',
#   'id': 274036},
#  {'license': 1,
#   'file_name': '000000255627.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000255627.jpg',
#   'height': 500,
#   'width': 333,
#   'date_captured': '2013-11-21 05:41:49',
#   'flickr_url': 'http://farm3.staticflickr.com/2783/4408548514_998c1c72bc_z.jpg',
#   'id': 255627},
#  {'license': 4,
#   'file_name': '000000396410.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000396410.jpg',
#   'height': 359,
#   'width': 640,
#   'date_captured': '2013-11-16 21:31:08',
#   'flickr_url': 'http://farm9.staticflickr.com/8152/7421703700_0fac6aa934_z.jpg',
#   'id': 396410},
#  {'license': 2,
#   'file_name': '000000019725.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000019725.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 00:09:16',
#   'flickr_url': 'http://farm9.staticflickr.com/8356/8304501081_61abef7070_z.jpg',
#   'id': 19725},
#  {'license': 5,
#   'file_name': '000000290952.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000290952.jpg',
#   'height': 235,
#   'width': 640,
#   'date_captured': '2013-11-17 08:21:46',
#   'flickr_url': 'http://farm4.staticflickr.com/3819/9315590661_704681f627_z.jpg',
#   'id': 290952},
#  {'license': 3,
#   'file_name': '000000332958.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000332958.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-19 22:20:45',
#   'flickr_url': 'http://farm1.staticflickr.com/151/423382403_50d208acff_z.jpg',
#   'id': 332958},
#  {'license': 1,
#   'file_name': '000000521221.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000521221.jpg',
#   'height': 384,
#   'width': 640,
#   'date_captured': '2013-11-15 21:57:58',
#   'flickr_url': 'http://farm7.staticflickr.com/6223/6231820585_b7f983c4ed_z.jpg',
#   'id': 521221},
#  {'license': 3,
#   'file_name': '000000190115.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000190115.jpg',
#   'height': 500,
#   'width': 500,
#   'date_captured': '2013-11-14 21:37:45',
#   'flickr_url': 'http://farm2.staticflickr.com/1217/1286830368_a1659cac6f_z.jpg',
#   'id': 190115},
#  {'license': 1,
#   'file_name': '000000083801.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000083801.jpg',
#   'height': 185,
#   'width': 640,
#   'date_captured': '2013-11-17 16:17:04',
#   'flickr_url': 'http://farm9.staticflickr.com/8011/7449746452_92039520c1_z.jpg',
#   'id': 83801},
#  {'license': 6,
#   'file_name': '000000212047.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000212047.jpg',
#   'height': 479,
#   'width': 640,
#   'date_captured': '2013-11-22 20:17:36',
#   'flickr_url': 'http://farm1.staticflickr.com/52/186718760_328f51dfa9_z.jpg',
#   'id': 212047},
#  {'license': 3,
#   'file_name': '000000550911.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000550911.jpg',
#   'height': 640,
#   'width': 427,
#   'date_captured': '2013-11-21 02:14:43',
#   'flickr_url': 'http://farm3.staticflickr.com/2886/9256631731_073fdb953f_z.jpg',
#   'id': 550911},
#  {'license': 3,
#   'file_name': '000000150685.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000150685.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-15 17:58:04',
#   'flickr_url': 'http://farm3.staticflickr.com/2640/3763159761_02d62db50b_z.jpg',
#   'id': 150685},
#  {'license': 4,
#   'file_name': '000000087812.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000087812.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 09:35:12',
#   'flickr_url': 'http://farm8.staticflickr.com/7415/8931723429_0d47735b02_z.jpg',
#   'id': 87812},
#  {'license': 5,
#   'file_name': '000000042366.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000042366.jpg',
#   'height': 433,
#   'width': 640,
#   'date_captured': '2013-11-16 22:54:26',
#   'flickr_url': 'http://farm4.staticflickr.com/3011/3083417495_26e47e1f4d_z.jpg',
#   'id': 42366},
#  {'license': 1,
#   'file_name': '000000530282.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000530282.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 16:04:02',
#   'flickr_url': 'http://farm8.staticflickr.com/7244/7187533002_7f7956118d_z.jpg',
#   'id': 530282},
#  {'license': 1,
#   'file_name': '000000515796.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000515796.jpg',
#   'height': 612,
#   'width': 612,
#   'date_captured': '2013-11-18 02:28:18',
#   'flickr_url': 'http://farm9.staticflickr.com/8077/8293453749_40e85f1777_z.jpg',
#   'id': 515796},
#  {'license': 1,
#   'file_name': '000000013901.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000013901.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 07:26:40',
#   'flickr_url': 'http://farm6.staticflickr.com/5466/9557209206_12fc1d6570_z.jpg',
#   'id': 13901},
#  {'license': 1,
#   'file_name': '000000074002.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000074002.jpg',
#   'height': 478,
#   'width': 640,
#   'date_captured': '2013-11-24 22:44:30',
#   'flickr_url': 'http://farm8.staticflickr.com/7320/9480561073_d3350fb0ea_z.jpg',
#   'id': 74002},
#  {'license': 1,
#   'file_name': '000000296192.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000296192.jpg',
#   'height': 640,
#   'width': 640,
#   'date_captured': '2013-11-17 06:35:24',
#   'flickr_url': 'http://farm8.staticflickr.com/7314/9325105338_3b8237c0be_z.jpg',
#   'id': 296192},
#  {'license': 4,
#   'file_name': '000000545409.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000545409.jpg',
#   'height': 500,
#   'width': 490,
#   'date_captured': '2013-11-18 13:21:20',
#   'flickr_url': 'http://farm2.staticflickr.com/1372/568881636_7ec3480eaf_z.jpg',
#   'id': 545409},
#  {'license': 3,
#   'file_name': '000000133464.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000133464.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-22 18:34:58',
#   'flickr_url': 'http://farm4.staticflickr.com/3137/2628299154_438548f123_z.jpg',
#   'id': 133464},
#  {'license': 3,
#   'file_name': '000000430096.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000430096.jpg',
#   'height': 429,
#   'width': 640,
#   'date_captured': '2013-11-19 22:03:06',
#   'flickr_url': 'http://farm4.staticflickr.com/3644/3364616664_486c85619e_z.jpg',
#   'id': 430096},
#  {'license': 3,
#   'file_name': '000000373748.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000373748.jpg',
#   'height': 500,
#   'width': 333,
#   'date_captured': '2013-11-24 03:35:20',
#   'flickr_url': 'http://farm1.staticflickr.com/63/195872660_fd76dc1ed4_z.jpg',
#   'id': 373748},
#  {'license': 1,
#   'file_name': '000000268982.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000268982.jpg',
#   'height': 640,
#   'width': 480,
#   'date_captured': '2013-11-20 15:08:43',
#   'flickr_url': 'http://farm1.staticflickr.com/28/46338624_2028595aa4_z.jpg',
#   'id': 268982},
#  {'license': 4,
#   'file_name': '000000567518.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000567518.jpg',
#   'height': 640,
#   'width': 478,
#   'date_captured': '2013-11-19 21:15:31',
#   'flickr_url': 'http://farm8.staticflickr.com/7202/6920809953_697936f1f0_z.jpg',
#   'id': 567518},
#  {'license': 4,
#   'file_name': '000000108451.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000108451.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-23 00:51:15',
#   'flickr_url': 'http://farm9.staticflickr.com/8011/7276890070_0cd6a38e7a_z.jpg',
#   'id': 108451},
#  {'license': 2,
#   'file_name': '000000276047.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000276047.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-16 21:53:54',
#   'flickr_url': 'http://farm9.staticflickr.com/8368/8353694338_7af0548521_z.jpg',
#   'id': 276047},
#  {'license': 2,
#   'file_name': '000000157170.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000157170.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-17 00:04:44',
#   'flickr_url': 'http://farm6.staticflickr.com/5050/5310788446_5012ceeb16_z.jpg',
#   'id': 157170},
#  {'license': 1,
#   'file_name': '000000572689.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000572689.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-18 04:37:15',
#   'flickr_url': 'http://farm4.staticflickr.com/3605/4081010692_625824c49f_z.jpg',
#   'id': 572689},
#  {'license': 1,
#   'file_name': '000000195768.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000195768.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-20 20:22:01',
#   'flickr_url': 'http://farm9.staticflickr.com/8543/8630921035_59ed19fbb7_z.jpg',
#   'id': 195768},
#  {'license': 1,
#   'file_name': '000000257102.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000257102.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-14 22:11:09',
#   'flickr_url': 'http://farm8.staticflickr.com/7240/6872015740_f050b99b32_z.jpg',
#   'id': 257102},
#  {'license': 5,
#   'file_name': '000000233093.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000233093.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-21 00:37:08',
#   'flickr_url': 'http://farm2.staticflickr.com/1192/782119812_caea4b878e_z.jpg',
#   'id': 233093},
#  {'license': 3,
#   'file_name': '000000439092.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000439092.jpg',
#   'height': 512,
#   'width': 640,
#   'date_captured': '2013-11-19 22:43:35',
#   'flickr_url': 'http://farm6.staticflickr.com/5140/5446947724_8f730f6576_z.jpg',
#   'id': 439092},
#  {'license': 3,
#   'file_name': '000000297724.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000297724.jpg',
#   'height': 500,
#   'width': 375,
#   'date_captured': '2013-11-24 10:32:25',
#   'flickr_url': 'http://farm4.staticflickr.com/3391/3562771710_063e999066_z.jpg',
#   'id': 297724},
#  {'license': 1,
#   'file_name': '000000534456.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000534456.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-21 22:53:56',
#   'flickr_url': 'http://farm2.staticflickr.com/1114/1261851710_b6ae833d84_z.jpg',
#   'id': 534456},
#  ...]

# %%
len(data['images'])
# Out:
# 25000

# %% [markdown]
# ## Get Mapping of Class Index to Class Label

# %%
import json

# Specify the filename (or path) to your JSON file
filename = "idx_to_label.json"

# Load the dictionary from the JSON file
with open(filename, 'r') as f:
    idx_to_label = json.load(f)

idx_to_label = {int(k): v for k, v in idx_to_label.items()}

# %%
idx_to_label[0]
# Out:
# 'person'

# %% [markdown]
# ## Load Image and Annotations from mini-coco dataset

# %%
import pandas as pd
df = pd.DataFrame(data['images'])
df
# Out:
#        license         file_name  \
# 0            1  000000231538.jpg
# 1            5  000000322749.jpg
# 2            3  000000318299.jpg
# 3            3  000000025290.jpg
# 4            3  000000020276.jpg
# ...        ...               ...
# 24995        4  000000465301.jpg
# 24996        3  000000281503.jpg
# 24997        3  000000260893.jpg
# 24998        4  000000405192.jpg
# 24999        6  000000381107.jpg
#
#                                                 coco_url  height  width  \
# 0      http://images.cocodataset.org/train2017/000000...     640    476
# 1      http://images.cocodataset.org/train2017/000000...     427    640
# 2      http://images.cocodataset.org/train2017/000000...     480    640
# 3      http://images.cocodataset.org/train2017/000000...     426    640
# 4      http://images.cocodataset.org/train2017/000000...     428    640
# ...                                                  ...     ...    ...
# 24995  http://images.cocodataset.org/train2017/000000...     375    500
# 24996  http://images.cocodataset.org/train2017/000000...     427    640
# 24997  http://images.cocodataset.org/train2017/000000...     425    640
# 24998  http://images.cocodataset.org/train2017/000000...     640    427
# 24999  http://images.cocodataset.org/train2017/000000...     480    640
#
#              date_captured                                         flickr_url  \
# 0      2013-11-18 12:00:52  http://farm4.staticflickr.com/3142/2804610447_...
# 1      2013-11-19 21:13:16  http://farm5.staticflickr.com/4093/4915514425_...
# 2      2013-11-17 17:58:55  http://farm4.staticflickr.com/3781/9068155095_...
# 3      2013-11-14 20:23:19  http://farm1.staticflickr.com/33/55074253_6d39...
# 4      2013-11-21 00:30:10  http://farm5.staticflickr.com/4132/5048683260_...
# ...                    ...                                                ...
# 24995  2013-11-21 21:00:16  http://farm5.staticflickr.com/4010/4386991761_...
# 24996  2013-11-22 22:33:06  http://farm4.staticflickr.com/3642/3921330424_...
# 24997  2013-11-24 20:40:46  http://farm6.staticflickr.com/5241/5373688358_...
# 24998  2013-11-20 15:08:16  http://farm5.staticflickr.com/4086/5043933537_...
# 24999  2013-11-16 03:04:37  http://farm7.staticflickr.com/6125/5945725738_...
#
#            id
# 0      231538
# 1      322749
# 2      318299
# 3       25290
# 4       20276
# ...       ...
# 24995  465301
# 24996  281503
# 24997  260893
# 24998  405192
# 24999  381107
#
# [25000 rows x 8 columns]

# %% [markdown]
# ## Run YOLO inference to get results from model

# %%
import cv2
from ultralytics import YOLO
from tqdm.auto import tqdm

model = YOLO("yolov8n.pt")

# %%
det_boxes = []
det_confidences = []
det_class_ids = []
filename = []
id = []

df = df.head(10)

img_path = '/workspace/datasets/coco_minitrain_25k/images/train2017/'
for row in tqdm(df.itertuples(), desc="Processing", total=len(df), unit=" imgs"):
    image_path = img_path + row.file_name
    image = cv2.imread(image_path)
    results = model(image, verbose=False)[0]

    filename.append(row.file_name)
    id.append(row.id) 
    det_boxes.append(results.boxes.xywh.cpu().numpy())
    det_confidences.append(results.boxes.conf.cpu().numpy())
    det_class_ids.append(results.boxes.cls.cpu().numpy())
# Out:
# Processing:   0%|          | 0/10 [00:00<?, ? imgs/s]

# %%
yolo_detections_df = pd.DataFrame({'filename': filename, 
                                   'id':id,
                                   'det_boxes': det_boxes, 
                                   'det_conf': det_confidences, 
                                   'det_category_id': det_class_ids})

yolo_detections_df['det_boxes'] = yolo_detections_df['det_boxes'].apply(lambda x: [[round(float(y), 2) for y in sublist] for sublist in x])
yolo_detections_df['det_conf'] = yolo_detections_df['det_conf'].apply(lambda x: [round(num, 4) for num in x])
yolo_detections_df['det_category_id'] = yolo_detections_df['det_category_id'].apply(lambda x: [int(num) for num in x])


yolo_detections_df
# Out:
#            filename      id  \
# 0  000000231538.jpg  231538
# 1  000000322749.jpg  322749
# 2  000000318299.jpg  318299
# 3  000000025290.jpg   25290
# 4  000000020276.jpg   20276
# 5  000000209692.jpg  209692
# 6  000000437607.jpg  437607
# 7  000000116389.jpg  116389
# 8  000000347238.jpg  347238
# 9  000000129801.jpg  129801
#
#                                            det_boxes  \
# 0  [[369.12, 374.82, 94.64, 367.55], [275.72, 360...
# 1  [[194.15, 80.24, 183.24, 151.9], [582.14, 249....
# 2  [[458.6, 221.3, 362.52, 239.65], [178.15, 203....
# 3  [[460.87, 165.48, 334.83, 326.56], [540.66, 33...
# 4  [[292.33, 211.56, 211.44, 191.84], [177.89, 30...
# 5  [[300.59, 310.68, 539.63, 444.07], [10.65, 354...
# 6  [[125.74, 204.09, 250.82, 164.99], [312.54, 19...
# 7                    [[320.8, 254.33, 68.39, 165.1]]
# 8  [[516.3, 222.73, 246.89, 271.71], [318.07, 199...
# 9  [[413.43, 200.07, 234.65, 232.24], [183.83, 21...
#
#                                             det_conf  \
# 0  [0.8767, 0.8523, 0.7863, 0.7315, 0.6548, 0.618...
# 1  [0.7612, 0.7044, 0.5148, 0.4506, 0.4182, 0.326...
# 2                           [0.9268, 0.8947, 0.2532]
# 3                                   [0.9171, 0.8854]
# 4                                   [0.8757, 0.8557]
# 5                   [0.4623, 0.3321, 0.3156, 0.2726]
# 6                            [0.859, 0.7791, 0.4693]
# 7                                           [0.8327]
# 8  [0.8545, 0.7607, 0.7547, 0.7325, 0.4696, 0.453...
# 9     [0.9217, 0.86, 0.8424, 0.3653, 0.3583, 0.2736]
#
#                      det_category_id
# 0    [0, 0, 0, 28, 0, 24, 28, 0, 28]
# 1       [50, 50, 51, 50, 50, 51, 51]
# 2                          [7, 7, 7]
# 3                            [0, 36]
# 4                            [0, 37]
# 5                       [7, 2, 2, 2]
# 6                          [6, 6, 6]
# 7                                [0]
# 8  [20, 20, 0, 0, 0, 0, 0, 0, 0, 20]
# 9                 [5, 7, 0, 0, 0, 0]

# %%
yolo_detections_df = yolo_detections_df.apply(pd.Series.explode)
yolo_detections_df.rename(columns={'id': 'image_id'}, inplace=True)
yolo_detections_df
# Out:
#            filename  image_id                         det_boxes det_conf  \
# 0  000000231538.jpg    231538   [369.12, 374.82, 94.64, 367.55]   0.8767
# 0  000000231538.jpg    231538  [275.72, 360.12, 117.38, 313.49]   0.8523
# 0  000000231538.jpg    231538    [144.19, 267.04, 30.54, 96.76]   0.7863
# 0  000000231538.jpg    231538    [286.19, 538.9, 123.33, 85.47]   0.7315
# 0  000000231538.jpg    231538    [183.74, 267.33, 36.12, 87.47]   0.6548
# 0  000000231538.jpg    231538    [191.79, 550.25, 88.6, 109.13]   0.6182
# 0  000000231538.jpg    231538  [102.13, 523.47, 194.88, 161.48]   0.5247
# 0  000000231538.jpg    231538    [212.96, 262.37, 23.27, 77.72]   0.4913
# 0  000000231538.jpg    231538  [285.47, 487.12, 123.05, 191.52]   0.3377
# 1  000000322749.jpg    322749    [194.15, 80.24, 183.24, 151.9]   0.7612
# 1  000000322749.jpg    322749  [582.14, 249.81, 114.77, 163.43]   0.7044
# 1  000000322749.jpg    322749    [317.68, 105.67, 85.97, 81.06]   0.5148
# 1  000000322749.jpg    322749   [508.36, 126.07, 260.89, 246.9]   0.4506
# 1  000000322749.jpg    322749    [340.34, 44.86, 132.61, 87.54]   0.4182
# 1  000000322749.jpg    322749    [384.18, 162.1, 59.75, 103.38]   0.3265
# 1  000000322749.jpg    322749     [501.29, 341.96, 68.19, 74.1]   0.3151
# 2  000000318299.jpg    318299    [458.6, 221.3, 362.52, 239.65]   0.9268
# 2  000000318299.jpg    318299  [178.15, 203.08, 301.25, 160.42]   0.8947
# 2  000000318299.jpg    318299     [17.86, 236.46, 35.53, 77.46]   0.2532
# 3  000000025290.jpg     25290  [460.87, 165.48, 334.83, 326.56]   0.9171
# 3  000000025290.jpg     25290    [540.66, 336.77, 198.06, 95.8]   0.8854
# 4  000000020276.jpg     20276  [292.33, 211.56, 211.44, 191.84]   0.8757
# 4  000000020276.jpg     20276   [177.89, 309.48, 116.63, 69.79]   0.8557
# 5  000000209692.jpg    209692  [300.59, 310.68, 539.63, 444.07]   0.4623
# 5  000000209692.jpg    209692      [10.65, 354.93, 21.3, 22.17]   0.3321
# 5  000000209692.jpg    209692     [27.12, 354.38, 29.48, 24.06]   0.3156
# 5  000000209692.jpg    209692     [20.26, 354.76, 40.51, 23.64]   0.2726
# 6  000000437607.jpg    437607  [125.74, 204.09, 250.82, 164.99]    0.859
# 6  000000437607.jpg    437607  [312.54, 198.31, 132.49, 144.37]   0.7791
# 6  000000437607.jpg    437607  [506.64, 219.33, 266.13, 157.85]   0.4693
# 7  000000116389.jpg    116389     [320.8, 254.33, 68.39, 165.1]   0.8327
# 8  000000347238.jpg    347238   [516.3, 222.73, 246.89, 271.71]   0.8545
# 8  000000347238.jpg    347238  [318.07, 199.28, 451.54, 231.87]   0.7607
# 8  000000347238.jpg    347238    [15.39, 209.78, 30.68, 118.98]   0.7547
# 8  000000347238.jpg    347238     [37.9, 216.05, 37.67, 122.79]   0.7325
# 8  000000347238.jpg    347238     [29.45, 278.37, 58.87, 92.41]   0.4696
# 8  000000347238.jpg    347238    [30.62, 366.16, 60.96, 113.98]   0.4539
# 8  000000347238.jpg    347238     [79.41, 218.46, 38.28, 122.7]   0.3686
# 8  000000347238.jpg    347238    [30.85, 326.85, 61.65, 192.59]   0.2974
# 8  000000347238.jpg    347238    [104.51, 218.47, 92.05, 123.0]   0.2642
# 8  000000347238.jpg    347238   [225.8, 195.33, 190.41, 215.97]   0.2564
# 9  000000129801.jpg    129801  [413.43, 200.07, 234.65, 232.24]   0.9217
# 9  000000129801.jpg    129801  [183.83, 213.03, 263.54, 129.21]     0.86
# 9  000000129801.jpg    129801    [583.16, 250.26, 29.64, 80.72]   0.8424
# 9  000000129801.jpg    129801      [549.16, 224.4, 9.99, 20.04]   0.3653
# 9  000000129801.jpg    129801     [519.33, 256.26, 15.67, 62.8]   0.3583
# 9  000000129801.jpg    129801    [411.42, 168.99, 47.85, 49.84]   0.2736
#
#   det_category_id
# 0               0
# 0               0
# 0               0
# 0              28
# 0               0
# 0              24
# 0              28
# 0               0
# 0              28
# 1              50
# 1              50
# 1              51
# 1              50
# 1              50
# 1              51
# 1              51
# 2               7
# 2               7
# 2               7
# 3               0
# 3              36
# 4               0
# 4              37
# 5               7
# 5               2
# 5               2
# 5               2
# 6               6
# 6               6
# 6               6
# 7               0
# 8              20
# 8              20
# 8               0
# 8               0
# 8               0
# 8               0
# 8               0
# 8               0
# 8               0
# 8              20
# 9               5
# 9               7
# 9               0
# 9               0
# 9               0
# 9               0

# %%
yolo_detections_df['det_category_label'] = yolo_detections_df['det_category_id'].map(idx_to_label)
yolo_detections_df
# Out:
#            filename  image_id                         det_boxes det_conf  \
# 0  000000231538.jpg    231538   [369.12, 374.82, 94.64, 367.55]   0.8767
# 0  000000231538.jpg    231538  [275.72, 360.12, 117.38, 313.49]   0.8523
# 0  000000231538.jpg    231538    [144.19, 267.04, 30.54, 96.76]   0.7863
# 0  000000231538.jpg    231538    [286.19, 538.9, 123.33, 85.47]   0.7315
# 0  000000231538.jpg    231538    [183.74, 267.33, 36.12, 87.47]   0.6548
# 0  000000231538.jpg    231538    [191.79, 550.25, 88.6, 109.13]   0.6182
# 0  000000231538.jpg    231538  [102.13, 523.47, 194.88, 161.48]   0.5247
# 0  000000231538.jpg    231538    [212.96, 262.37, 23.27, 77.72]   0.4913
# 0  000000231538.jpg    231538  [285.47, 487.12, 123.05, 191.52]   0.3377
# 1  000000322749.jpg    322749    [194.15, 80.24, 183.24, 151.9]   0.7612
# 1  000000322749.jpg    322749  [582.14, 249.81, 114.77, 163.43]   0.7044
# 1  000000322749.jpg    322749    [317.68, 105.67, 85.97, 81.06]   0.5148
# 1  000000322749.jpg    322749   [508.36, 126.07, 260.89, 246.9]   0.4506
# 1  000000322749.jpg    322749    [340.34, 44.86, 132.61, 87.54]   0.4182
# 1  000000322749.jpg    322749    [384.18, 162.1, 59.75, 103.38]   0.3265
# 1  000000322749.jpg    322749     [501.29, 341.96, 68.19, 74.1]   0.3151
# 2  000000318299.jpg    318299    [458.6, 221.3, 362.52, 239.65]   0.9268
# 2  000000318299.jpg    318299  [178.15, 203.08, 301.25, 160.42]   0.8947
# 2  000000318299.jpg    318299     [17.86, 236.46, 35.53, 77.46]   0.2532
# 3  000000025290.jpg     25290  [460.87, 165.48, 334.83, 326.56]   0.9171
# 3  000000025290.jpg     25290    [540.66, 336.77, 198.06, 95.8]   0.8854
# 4  000000020276.jpg     20276  [292.33, 211.56, 211.44, 191.84]   0.8757
# 4  000000020276.jpg     20276   [177.89, 309.48, 116.63, 69.79]   0.8557
# 5  000000209692.jpg    209692  [300.59, 310.68, 539.63, 444.07]   0.4623
# 5  000000209692.jpg    209692      [10.65, 354.93, 21.3, 22.17]   0.3321
# 5  000000209692.jpg    209692     [27.12, 354.38, 29.48, 24.06]   0.3156
# 5  000000209692.jpg    209692     [20.26, 354.76, 40.51, 23.64]   0.2726
# 6  000000437607.jpg    437607  [125.74, 204.09, 250.82, 164.99]    0.859
# 6  000000437607.jpg    437607  [312.54, 198.31, 132.49, 144.37]   0.7791
# 6  000000437607.jpg    437607  [506.64, 219.33, 266.13, 157.85]   0.4693
# 7  000000116389.jpg    116389     [320.8, 254.33, 68.39, 165.1]   0.8327
# 8  000000347238.jpg    347238   [516.3, 222.73, 246.89, 271.71]   0.8545
# 8  000000347238.jpg    347238  [318.07, 199.28, 451.54, 231.87]   0.7607
# 8  000000347238.jpg    347238    [15.39, 209.78, 30.68, 118.98]   0.7547
# 8  000000347238.jpg    347238     [37.9, 216.05, 37.67, 122.79]   0.7325
# 8  000000347238.jpg    347238     [29.45, 278.37, 58.87, 92.41]   0.4696
# 8  000000347238.jpg    347238    [30.62, 366.16, 60.96, 113.98]   0.4539
# 8  000000347238.jpg    347238     [79.41, 218.46, 38.28, 122.7]   0.3686
# 8  000000347238.jpg    347238    [30.85, 326.85, 61.65, 192.59]   0.2974
# 8  000000347238.jpg    347238    [104.51, 218.47, 92.05, 123.0]   0.2642
# 8  000000347238.jpg    347238   [225.8, 195.33, 190.41, 215.97]   0.2564
# 9  000000129801.jpg    129801  [413.43, 200.07, 234.65, 232.24]   0.9217
# 9  000000129801.jpg    129801  [183.83, 213.03, 263.54, 129.21]     0.86
# 9  000000129801.jpg    129801    [583.16, 250.26, 29.64, 80.72]   0.8424
# 9  000000129801.jpg    129801      [549.16, 224.4, 9.99, 20.04]   0.3653
# 9  000000129801.jpg    129801     [519.33, 256.26, 15.67, 62.8]   0.3583
# 9  000000129801.jpg    129801    [411.42, 168.99, 47.85, 49.84]   0.2736
#
#   det_category_id det_category_label
# 0               0             person
# 0               0             person
# 0               0             person
# 0              28           suitcase
# 0               0             person
# 0              24           backpack
# 0              28           suitcase
# 0               0             person
# 0              28           suitcase
# 1              50           broccoli
# 1              50           broccoli
# 1              51             carrot
# 1              50           broccoli
# 1              50           broccoli
# 1              51             carrot
# 1              51             carrot
# 2               7              truck
# 2               7              truck
# 2               7              truck
# 3               0             person
# 3              36         skateboard
# 4               0             person
# 4              37          surfboard
# 5               7              truck
# 5               2                car
# 5               2                car
# 5               2                car
# 6               6              train
# 6               6              train
# 6               6              train
# 7               0             person
# 8              20           elephant
# 8              20           elephant
# 8               0             person
# 8               0             person
# 8               0             person
# 8               0             person
# 8               0             person
# 8               0             person
# 8               0             person
# 8              20           elephant
# 9               5                bus
# 9               7              truck
# 9               0             person
# 9               0             person
# 9               0             person
# 9               0             person

# %% [markdown]
# YOLO outputs bbox in cxcywh format. We need to convert it into xywh format

# %%
def convert_cxcywh_to_xywh(box):
    cx, cy, w, h = box
    x = cx - w / 2
    y = cy - h / 2
    return [x, y, w, h]

yolo_detections_df['det_boxes'] = yolo_detections_df['det_boxes'].apply(convert_cxcywh_to_xywh)

# %%
yolo_detections_df
# Out:
#            filename  image_id  \
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 0  000000231538.jpg    231538
# 1  000000322749.jpg    322749
# 1  000000322749.jpg    322749
# 1  000000322749.jpg    322749
# 1  000000322749.jpg    322749
# 1  000000322749.jpg    322749
# 1  000000322749.jpg    322749
# 1  000000322749.jpg    322749
# 2  000000318299.jpg    318299
# 2  000000318299.jpg    318299
# 2  000000318299.jpg    318299
# 3  000000025290.jpg     25290
# 3  000000025290.jpg     25290
# 4  000000020276.jpg     20276
# 4  000000020276.jpg     20276
# 5  000000209692.jpg    209692
# 5  000000209692.jpg    209692
# 5  000000209692.jpg    209692
# 5  000000209692.jpg    209692
# 6  000000437607.jpg    437607
# 6  000000437607.jpg    437607
# 6  000000437607.jpg    437607
# 7  000000116389.jpg    116389
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 8  000000347238.jpg    347238
# 9  000000129801.jpg    129801
# 9  000000129801.jpg    129801
# 9  000000129801.jpg    129801
# 9  000000129801.jpg    129801
# 9  000000129801.jpg    129801
# 9  000000129801.jpg    129801
#
#                                            det_boxes det_conf det_category_id  \
# 0                    [321.8, 191.045, 94.64, 367.55]   0.8767               0
# 0      [217.03000000000003, 203.375, 117.38, 313.49]   0.8523               0
# 0         [128.92, 218.66000000000003, 30.54, 96.76]   0.7863               0
# 0       [224.525, 496.16499999999996, 123.33, 85.47]   0.7315              28
# 0         [165.68, 223.59499999999997, 36.12, 87.47]   0.6548               0
# 0                    [147.49, 495.685, 88.6, 109.13]   0.6182              24
# 0        [4.689999999999998, 442.73, 194.88, 161.48]   0.5247              28
# 0         [201.32500000000002, 223.51, 23.27, 77.72]   0.4913               0
# 0       [223.94500000000002, 391.36, 123.05, 191.52]   0.3377              28
# 1         [102.53, 4.289999999999992, 183.24, 151.9]   0.7612              50
# 1                 [524.755, 168.095, 114.77, 163.43]   0.7044              50
# 1                     [274.695, 65.14, 85.97, 81.06]   0.5148              51
# 1       [377.915, 2.6199999999999903, 260.89, 246.9]   0.4506              50
# 1  [274.03499999999997, 1.0899999999999963, 132.6...   0.4182              50
# 1                   [354.305, 110.41, 59.75, 103.38]   0.3265              51
# 1  [467.19500000000005, 304.90999999999997, 68.19...   0.3151              51
# 2  [277.34000000000003, 101.47500000000001, 362.5...   0.9268               7
# 2  [27.525000000000006, 122.87000000000002, 301.2...   0.8947               7
# 2  [0.09499999999999886, 197.73000000000002, 35.5...   0.2532               7
# 3  [293.45500000000004, 2.1999999999999886, 334.8...   0.9171               0
# 3                     [441.63, 288.87, 198.06, 95.8]   0.8854              36
# 4       [186.60999999999999, 115.64, 211.44, 191.84]   0.8757               0
# 4  [119.57499999999999, 274.58500000000004, 116.6...   0.8557              37
# 5  [30.774999999999977, 88.64500000000001, 539.63...   0.4623               7
# 5                        [0.0, 343.845, 21.3, 22.17]   0.3321               2
# 5                      [12.38, 342.35, 29.48, 24.06]   0.3156               2
# 5       [0.005000000000002558, 342.94, 40.51, 23.64]   0.2726               2
# 6      [0.3299999999999983, 121.595, 250.82, 164.99]    0.859               6
# 6      [246.29500000000002, 126.125, 132.49, 144.37]   0.7791               6
# 6      [373.575, 140.40500000000003, 266.13, 157.85]   0.4693               6
# 7        [286.605, 171.78000000000003, 68.39, 165.1]   0.8327               0
# 8       [392.85499999999996, 86.875, 246.89, 271.71]   0.8545              20
# 8        [92.29999999999998, 83.345, 451.54, 231.87]   0.7607              20
# 8       [0.05000000000000071, 150.29, 30.68, 118.98]   0.7547               0
# 8       [19.064999999999998, 154.655, 37.67, 122.79]   0.7325               0
# 8  [0.015000000000000568, 232.16500000000002, 58....   0.4696               0
# 8       [0.14000000000000057, 309.17, 60.96, 113.98]   0.4539               0
# 8         [60.269999999999996, 157.11, 38.28, 122.7]   0.3686               0
# 8      [0.02500000000000213, 230.555, 61.65, 192.59]   0.2974               0
# 8          [58.48500000000001, 156.97, 92.05, 123.0]   0.2642               0
# 8  [130.59500000000003, 87.34500000000001, 190.41...   0.2564              20
# 9       [296.105, 83.94999999999999, 234.65, 232.24]   0.9217               5
# 9                   [52.06, 148.425, 263.54, 129.21]     0.86               7
# 9  [568.3399999999999, 209.89999999999998, 29.64,...   0.8424               0
# 9                     [544.165, 214.38, 9.99, 20.04]   0.3653               0
# 9  [511.49500000000006, 224.85999999999999, 15.67...   0.3583               0
# 9                    [387.495, 144.07, 47.85, 49.84]   0.2736               0
#
#   det_category_label
# 0             person
# 0             person
# 0             person
# 0           suitcase
# 0             person
# 0           backpack
# 0           suitcase
# 0             person
# 0           suitcase
# 1           broccoli
# 1           broccoli
# 1             carrot
# 1           broccoli
# 1           broccoli
# 1             carrot
# 1             carrot
# 2              truck
# 2              truck
# 2              truck
# 3             person
# 3         skateboard
# 4             person
# 4          surfboard
# 5              truck
# 5                car
# 5                car
# 5                car
# 6              train
# 6              train
# 6              train
# 7             person
# 8           elephant
# 8           elephant
# 8             person
# 8             person
# 8             person
# 8             person
# 8             person
# 8             person
# 8             person
# 8           elephant
# 9                bus
# 9              truck
# 9             person
# 9             person
# 9             person
# 9             person

# %%
# Plot to check if detections and conversions are right

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image


for index, row in yolo_detections_df.sample(5).iterrows():

    filename_path = img_path + row['filename']
    img = Image.open(filename_path)

    fig, ax = plt.subplots(1)
    ax.imshow(img)

    x, y, w, h = row['det_boxes']
    rect = patches.Rectangle((x, y), w, h, linewidth=1, edgecolor='r', facecolor='none', label=row['det_category_label'])
    ax.add_patch(rect)
    plt.text(x, y, row['det_category_label'], color='white', fontsize=12, backgroundcolor='red')

plt.show()

# %% [markdown]
# ## Get GT from annotations

# %%
df_annot = pd.DataFrame(data['annotations'])
df_annot # bbox is xywh format
# Out:
#                                              segmentation         area  \
# 0       [[314.97, 458.79, 333.66, 307.78, 326.47, 253....  21914.66615
# 1       [[269.17, 506.98, 220.49, 509.85, 213.33, 498....  19889.56405
# 2       [[190.87, 309.05, 183.08, 308.55, 180.06, 305....   1202.36040
# 3       [[228.79, 516.28, 281.85, 501.31, 287.97, 499....   7523.06275
# 4       [[213.11, 306.11, 199.9, 306.72, 202.91, 296.5...   1544.49695
# ...                                                   ...          ...
# 183541  [[391.96, 59.55, 396.04, 50.02, 392.64, 44.58,...   1510.91595
# 183542  [[28.86, 2.36, 21.92, 28.14, 40.75, 44.0, 78.4...  39808.83950
# 183543  [[640.0, 277.24, 594.08, 276.16, 583.32, 282.6...  22042.70610
# 183544  [[66.03, 239.2, 96.23, 239.2, 101.62, 232.73, ...    170.60765
# 183545  [[263.45, 273.12, 262.7, 259.13, 264.2, 251.13...   2050.52765
#
#         iscrowd  image_id                              bbox  category_id  \
# 0             0    231538  [314.97, 192.72, 102.11, 366.74]            1
# 1             0    231538  [213.33, 202.02, 117.41, 307.83]            1
# 2             0    231538     [177.8, 225.12, 25.63, 83.93]            1
# 3             0    231538   [227.43, 499.95, 120.41, 80.28]           33
# 4             0    231538     [199.9, 221.44, 27.03, 85.28]            1
# ...         ...       ...                               ...          ...
# 183541        0    405192      [386.52, 0.36, 40.48, 65.99]            1
# 183542        0    405192      [21.92, 0.0, 354.91, 180.81]            1
# 183543        0    381107  [224.93, 171.77, 415.07, 125.92]            5
# 183544        0    381107     [66.03, 232.73, 35.59, 11.87]            5
# 183545        0    381107     [262.7, 245.14, 77.19, 36.97]            8
#
#              id
# 0        481949
# 1        498229
# 2        536668
# 3       1184351
# 4       1238132
# ...         ...
# 183541  1687726
# 183542  1712286
# 183543   158060
# 183544   158614
# 183545   399564
#
# [183546 rows x 7 columns]

# %%
# In the annotations, the index class starts from 1. In yolo it starts from 0. Let standardize them.
df_annot['category_id'] = df_annot['category_id'] - 1
df_annot
# Out:
#                                              segmentation         area  \
# 0       [[314.97, 458.79, 333.66, 307.78, 326.47, 253....  21914.66615
# 1       [[269.17, 506.98, 220.49, 509.85, 213.33, 498....  19889.56405
# 2       [[190.87, 309.05, 183.08, 308.55, 180.06, 305....   1202.36040
# 3       [[228.79, 516.28, 281.85, 501.31, 287.97, 499....   7523.06275
# 4       [[213.11, 306.11, 199.9, 306.72, 202.91, 296.5...   1544.49695
# ...                                                   ...          ...
# 183541  [[391.96, 59.55, 396.04, 50.02, 392.64, 44.58,...   1510.91595
# 183542  [[28.86, 2.36, 21.92, 28.14, 40.75, 44.0, 78.4...  39808.83950
# 183543  [[640.0, 277.24, 594.08, 276.16, 583.32, 282.6...  22042.70610
# 183544  [[66.03, 239.2, 96.23, 239.2, 101.62, 232.73, ...    170.60765
# 183545  [[263.45, 273.12, 262.7, 259.13, 264.2, 251.13...   2050.52765
#
#         iscrowd  image_id                              bbox  category_id  \
# 0             0    231538  [314.97, 192.72, 102.11, 366.74]            0
# 1             0    231538  [213.33, 202.02, 117.41, 307.83]            0
# 2             0    231538     [177.8, 225.12, 25.63, 83.93]            0
# 3             0    231538   [227.43, 499.95, 120.41, 80.28]           32
# 4             0    231538     [199.9, 221.44, 27.03, 85.28]            0
# ...         ...       ...                               ...          ...
# 183541        0    405192      [386.52, 0.36, 40.48, 65.99]            0
# 183542        0    405192      [21.92, 0.0, 354.91, 180.81]            0
# 183543        0    381107  [224.93, 171.77, 415.07, 125.92]            4
# 183544        0    381107     [66.03, 232.73, 35.59, 11.87]            4
# 183545        0    381107     [262.7, 245.14, 77.19, 36.97]            7
#
#              id
# 0        481949
# 1        498229
# 2        536668
# 3       1184351
# 4       1238132
# ...         ...
# 183541  1687726
# 183542  1712286
# 183543   158060
# 183544   158614
# 183545   399564
#
# [183546 rows x 7 columns]

# %%
# Drop unnecssary columns and rename for clarity.

df_annot = df_annot[['image_id', 'bbox', 'category_id']]
df_annot.rename(columns={'bbox':'true_bbox', 'category_id':'true_category_id'}, inplace=True)
df_annot
# Out:
# /tmp/ipykernel_3060/2504949157.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_annot.rename(columns={'bbox':'true_bbox', 'category_id':'true_category_id'}, inplace=True)
#         image_id                         true_bbox  true_category_id
# 0         231538  [314.97, 192.72, 102.11, 366.74]                 0
# 1         231538  [213.33, 202.02, 117.41, 307.83]                 0
# 2         231538     [177.8, 225.12, 25.63, 83.93]                 0
# 3         231538   [227.43, 499.95, 120.41, 80.28]                32
# 4         231538     [199.9, 221.44, 27.03, 85.28]                 0
# ...          ...                               ...               ...
# 183541    405192      [386.52, 0.36, 40.48, 65.99]                 0
# 183542    405192      [21.92, 0.0, 354.91, 180.81]                 0
# 183543    381107  [224.93, 171.77, 415.07, 125.92]                 4
# 183544    381107     [66.03, 232.73, 35.59, 11.87]                 4
# 183545    381107     [262.7, 245.14, 77.19, 36.97]                 7
#
# [183546 rows x 3 columns]

# %% [markdown]
# ## Merge into a dataframe

# %%
merged_df = pd.merge(yolo_detections_df, df_annot, on='image_id', how='inner')

# Reorder the columns to match the specified order
merged_df = merged_df[['filename', 'image_id', 'true_bbox', 'true_category_id', 'det_boxes', 'det_conf', 'det_category_id']]
merged_df

# %%
merged_df['det_category_label'] = merged_df['det_category_id'].map(idx_to_label)
merged_df['true_category_label'] = merged_df['true_category_id'].map(idx_to_label)

# %%
merged_df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image


def draw_bbox(ax, bbox, edgecolor, label):
    # Draw a bounding box with the specified parameters
    rect = patches.Rectangle((bbox[0], bbox[1]), bbox[2], bbox[3], linewidth=2, edgecolor=edgecolor, facecolor='none', label=label)
    ax.add_patch(rect)

def plot_bboxes(row):
    # Open the image
    image = Image.open(img_path+row['filename'])
    fig, ax = plt.subplots(1)
    ax.imshow(image)

    # Directly use the bounding box values
    true_bbox = row['true_bbox']
    det_boxes = row['det_boxes']

    # Draw true and detected bounding boxes
    draw_bbox(ax, true_bbox, 'g', f'True: {row["true_category_label"]}')
    draw_bbox(ax, det_boxes, 'r', f'Detected: {row["det_category_label"]}')

    # Legend
    plt.legend(loc='upper right')
    plt.show()

# Plot bounding boxes for each row in the dataframe
for index, row in merged_df.head(5).iterrows():
    # Convert string representations of lists to actual lists if they are strings
    if isinstance(row['true_bbox'], str):
        row['true_bbox'] = eval(row['true_bbox'])
    if isinstance(row['det_boxes'], str):
        row['det_boxes'] = eval(row['det_boxes'])

    plot_bboxes(row)
