# %%
import pandas as pd

df = pd.read_parquet('full_oi_val_set_eva02.parquet')
df
# Out:
#                                                                       filename  \
# 0        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 1        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 2        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 3        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 4        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# ...                                                                        ...
# 1465654  /workspace/yolo_v8_training/oiv7_full/validation/c0762f4b3f97eaca.jpg
# 1465655  /workspace/yolo_v8_training/oiv7_full/validation/436d9265a1138325.jpg
# 1465656  /workspace/yolo_v8_training/oiv7_full/validation/436d9265a1138325.jpg
# 1465657  /workspace/yolo_v8_training/oiv7_full/validation/436d9265a1138325.jpg
# 1465658  /workspace/yolo_v8_training/oiv7_full/validation/436d9265a1138325.jpg
#
#                              label  confidence  col_x  row_y  width  height
# 0                     bowling_ball    0.985785    510    358     34      35
# 1                     bowling_ball    0.983798    888    490    136     190
# 2                             jean    0.902699    374    191    103     246
# 3        speaker_(stero_equipment)    0.896985    401     80     27      26
# 4                             shoe    0.823303    387    424     62      63
# ...                            ...         ...    ...    ...    ...     ...
# 1465654                      clasp    0.105013    363     95     11       6
# 1465655         statue_(sculpture)    0.804613    513     78    268     431
# 1465656         statue_(sculpture)    0.689743     48      1    190     279
# 1465657                  sculpture    0.141827      1      2    782     692
# 1465658                  sculpture    0.104643      4      5    234     372
#
# [1465659 rows x 7 columns]

# %%
# Get rows with person label
df = df[df['label'] == 'bowling_ball'] 
df
# Out:
#                                                                       filename  \
# 0        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 1        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 18       /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 2680     /workspace/yolo_v8_training/oiv7_full/validation/1a42a0dba80e270b.jpg
# 31920    /workspace/yolo_v8_training/oiv7_full/validation/e1a367e16b4e07fb.jpg
# ...                                                                        ...
# 1431689  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431690  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431692  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431695  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431698  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
#
#                 label  confidence  col_x  row_y  width  height
# 0        bowling_ball    0.985785    510    358     34      35
# 1        bowling_ball    0.983798    888    490    136     190
# 18       bowling_ball    0.327746    845    465     71      40
# 2680     bowling_ball    0.943042    482    799     46      41
# 31920    bowling_ball    0.938702    301     49     57      56
# ...               ...         ...    ...    ...    ...     ...
# 1431689  bowling_ball    0.203796     53    455     76      95
# 1431690  bowling_ball    0.200123    289    583     31      77
# 1431692  bowling_ball    0.173466     50    751     73      93
# 1431695  bowling_ball    0.146962    161    684     60      91
# 1431698  bowling_ball    0.116848     51    607     75      95
#
# [541 rows x 7 columns]

# %%
new_df = pd.DataFrame({
    'filename': df['filename'],
    'label': df['label'],
    'confidence': df['confidence'],
    'x1': df['col_x'],
    'y1': df['row_y'],
    'x2': df['col_x'] + df['width'],
    'y2': df['row_y'] + df['height']
})

# Assign the new DataFrame back to 'df' if desired
df = new_df

# %%
df
# Out:
#                                                                       filename  \
# 0        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 1        /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 18       /workspace/yolo_v8_training/oiv7_full/validation/9d2952737fde3523.jpg
# 2680     /workspace/yolo_v8_training/oiv7_full/validation/1a42a0dba80e270b.jpg
# 31920    /workspace/yolo_v8_training/oiv7_full/validation/e1a367e16b4e07fb.jpg
# ...                                                                        ...
# 1431689  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431690  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431692  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431695  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
# 1431698  /workspace/yolo_v8_training/oiv7_full/validation/97a0add3f8f47b65.jpg
#
#                 label  confidence   x1   y1    x2   y2
# 0        bowling_ball    0.985785  510  358   544  393
# 1        bowling_ball    0.983798  888  490  1024  680
# 18       bowling_ball    0.327746  845  465   916  505
# 2680     bowling_ball    0.943042  482  799   528  840
# 31920    bowling_ball    0.938702  301   49   358  105
# ...               ...         ...  ...  ...   ...  ...
# 1431689  bowling_ball    0.203796   53  455   129  550
# 1431690  bowling_ball    0.200123  289  583   320  660
# 1431692  bowling_ball    0.173466   50  751   123  844
# 1431695  bowling_ball    0.146962  161  684   221  775
# 1431698  bowling_ball    0.116848   51  607   126  702
#
# [541 rows x 7 columns]

# %%
import os
import xml.etree.ElementTree as ET
from PIL import Image
from xml.dom import minidom


def create_object_element(object_data):
    obj_elem = ET.Element('object')
    ET.SubElement(obj_elem, 'name').text = str(object_data['label'])
    ET.SubElement(obj_elem, 'pose').text = 'Unspecified'
    ET.SubElement(obj_elem, 'truncated').text = '0'
    ET.SubElement(obj_elem, 'difficult').text = '0'
    
    bndbox = ET.SubElement(obj_elem, 'bndbox')
    ET.SubElement(bndbox, 'xmin').text = str(object_data['x1'])
    ET.SubElement(bndbox, 'ymin').text = str(object_data['y1'])
    ET.SubElement(bndbox, 'xmax').text = str(object_data['x2'])
    ET.SubElement(bndbox, 'ymax').text = str(object_data['y2'])
    
    return obj_elem

def create_voc_xml(filename, objects, output_dir):
    annotation = ET.Element('annotation')
    ET.SubElement(annotation, 'filename').text = os.path.basename(filename)
    
    image = Image.open(filename)
    width, height = image.size
    
    size = ET.SubElement(annotation, 'size')
    ET.SubElement(size, 'width').text = str(width)
    ET.SubElement(size, 'height').text = str(height)
    ET.SubElement(size, 'depth').text = str(len(image.getbands()))
    
    for object_data in objects:
        annotation.append(create_object_element(object_data))
    
    # Create a new XML document
    xml_str = ET.tostring(annotation, encoding='utf-8')
    dom = minidom.parseString(xml_str)
    
    # Pretty-print the XML with indentation
    pretty_xml = dom.toprettyxml(indent='    ')
    
    output_file = os.path.join(output_dir, f"{os.path.splitext(os.path.basename(filename))[0]}.xml")
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(pretty_xml)

# %%
import os
from tqdm.auto import tqdm

output_directory = 'pascal_voc_annotations_bowling_ball'
os.makedirs(output_directory, exist_ok=True)

grouped_df = df.groupby('filename').apply(lambda x: x.to_dict('records')).reset_index(name='objects')

# %%
for row in tqdm(grouped_df.itertuples(index=False), total=len(grouped_df), desc='Generating annotations', unit=' imgs'):
    filename = row.filename
    objects = row.objects
    create_voc_xml(filename, objects, output_directory)
# Out:
# Generating annotations:   0%|          | 0/95 [00:00<?, ? imgs/s]

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

def plot_random_image_with_bounding_boxes(xml_folder, image_folder, num_images):
    # Get the list of XML files in the folder
    xml_files = [file for file in os.listdir(xml_folder) if file.endswith('.xml')]
    
    # Randomly select num_images XML files
    random_xml_files = random.sample(xml_files, num_images)
    
    # Create a figure with subplots for each image
    fig, axes = plt.subplots(1, num_images, figsize=(10 * num_images, 10))
    
    # Iterate over the randomly selected XML files
    for i, xml_file in enumerate(random_xml_files):
        xml_path = os.path.join(xml_folder, xml_file)
        
        # Parse the XML file
        tree = ET.parse(xml_path)
        root = tree.getroot()
        
        # Get the image filename from the XML
        image_filename = root.find('filename').text
        image_path = os.path.join(image_folder, image_filename)
        
        # Read the image
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Extract the bounding box information
        for obj in root.findall('object'):
            bndbox = obj.find('bndbox')
            xmin = int(bndbox.find('xmin').text)
            ymin = int(bndbox.find('ymin').text)
            xmax = int(bndbox.find('xmax').text)
            ymax = int(bndbox.find('ymax').text)
            class_id = obj.find('name').text
            
            # Draw the bounding box on the image
            cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)
            
            # Put the class ID text above the bounding box
            cv2.putText(image, class_id, (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        
        # Plot the image with bounding boxes and class IDs in the corresponding subplot
        axes[i].imshow(image)
        axes[i].axis('off')
    
    # Adjust the spacing between subplots
    plt.tight_layout()
    
    # Display the plots
    plt.show()

# %%
# %matplotlib inline

image_folder = '/workspace/yolo_v8_training/oiv7_full/validation/'
xml_folder = 'pascal_voc_annotations_bowling_ball/'

plot_random_image_with_bounding_boxes(xml_folder, image_folder, num_images=3)
