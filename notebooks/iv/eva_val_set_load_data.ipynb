# %%
import pandas as pd

df = pd.read_parquet('full_oi_train_set_eva02.parquet')
df
# Out:
#                                                    filename  \
# 0         /workspace/yolo_v8_training/oiv7_full/train/a8...
# 1         /workspace/yolo_v8_training/oiv7_full/train/a8...
# 2         /workspace/yolo_v8_training/oiv7_full/train/a8...
# 3         /workspace/yolo_v8_training/oiv7_full/train/a8...
# 4         /workspace/yolo_v8_training/oiv7_full/train/a8...
# ...                                                     ...
# 97567846  /workspace/yolo_v8_training/oiv7_full/train/75...
# 97567847  /workspace/yolo_v8_training/oiv7_full/train/75...
# 97567848  /workspace/yolo_v8_training/oiv7_full/train/75...
# 97567849  /workspace/yolo_v8_training/oiv7_full/train/75...
# 97567850  /workspace/yolo_v8_training/oiv7_full/train/75...
#
#                             label  confidence  col_x  row_y  width  height
# 0                            sock    0.943716   2620    560     61     126
# 1                            sock    0.937813   2776    531     88     144
# 2                            sock    0.928109    507    574     75     140
# 3                            sock    0.892527   3688    708    102     163
# 4                     short_pants    0.873567   2613    366    192     151
# ...                           ...         ...    ...    ...    ...     ...
# 97567846  window_box_(for_plants)    0.105930      1    556    118      15
# 97567847                 flagpole    0.105515    871     86     91      47
# 97567848              streetlight    0.103922    418    307     68      23
# 97567849                     pole    0.103065    945      0     79     279
# 97567850                  antenna    0.100473    110    189     22      83
#
# [97567851 rows x 7 columns]

# %%
# Get rows with person label
df = df[df['label'] == 'bowling_ball'] 
df
# Out:
#                                                    filename         label  \
# 41589     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41597     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41603     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41610     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41614     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# ...                                                     ...           ...
# 97469727  /workspace/yolo_v8_training/oiv7_full/train/5f...  bowling_ball
# 97524523  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97524534  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97524608  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97551809  /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
#
#           confidence  col_x  row_y  width  height
# 41589       0.282834   1014    385      9      14
# 41597       0.240335    953    382      9      16
# 41603       0.209357    944    382      8      15
# 41610       0.157041    963    383     11      17
# 41614       0.146558   1003    385      9      15
# ...              ...    ...    ...    ...     ...
# 97469727    0.195416    334     99     30      35
# 97524523    0.917035    492     62    117      78
# 97524534    0.803490    639     98     23      28
# 97524608    0.252943    582     69     60      57
# 97551809    0.232084    887    357     23      14
#
# [15617 rows x 7 columns]

# %%
df
# Out:
#                                                    filename         label  \
# 41589     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41597     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41603     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41610     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41614     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# ...                                                     ...           ...
# 97469727  /workspace/yolo_v8_training/oiv7_full/train/5f...  bowling_ball
# 97524523  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97524534  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97524608  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97551809  /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
#
#           confidence  col_x  row_y  width  height
# 41589       0.282834   1014    385      9      14
# 41597       0.240335    953    382      9      16
# 41603       0.209357    944    382      8      15
# 41610       0.157041    963    383     11      17
# 41614       0.146558   1003    385      9      15
# ...              ...    ...    ...    ...     ...
# 97469727    0.195416    334     99     30      35
# 97524523    0.917035    492     62    117      78
# 97524534    0.803490    639     98     23      28
# 97524608    0.252943    582     69     60      57
# 97551809    0.232084    887    357     23      14
#
# [15617 rows x 7 columns]

# %%
new_df = pd.DataFrame({
    'filename': df['filename'],
    'label': df['label'],
    'confidence': df['confidence'],
    'x1': df['col_x'],
    'y1': df['row_y'],
    'x2': df['col_x'] + df['width'],
    'y2': df['row_y'] + df['height']
})

df = new_df

# %%
df
# Out:
#                                                    filename         label  \
# 41589     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41597     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41603     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41610     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# 41614     /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
# ...                                                     ...           ...
# 97469727  /workspace/yolo_v8_training/oiv7_full/train/5f...  bowling_ball
# 97524523  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97524534  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97524608  /workspace/yolo_v8_training/oiv7_full/train/5b...  bowling_ball
# 97551809  /workspace/yolo_v8_training/oiv7_full/train/df...  bowling_ball
#
#           confidence    x1   y1    x2   y2
# 41589       0.282834  1014  385  1023  399
# 41597       0.240335   953  382   962  398
# 41603       0.209357   944  382   952  397
# 41610       0.157041   963  383   974  400
# 41614       0.146558  1003  385  1012  400
# ...              ...   ...  ...   ...  ...
# 97469727    0.195416   334   99   364  134
# 97524523    0.917035   492   62   609  140
# 97524534    0.803490   639   98   662  126
# 97524608    0.252943   582   69   642  126
# 97551809    0.232084   887  357   910  371
#
# [15617 rows x 7 columns]

# %%
import os
import xml.etree.ElementTree as ET
from PIL import Image
from xml.dom import minidom


def create_object_element(object_data):
    obj_elem = ET.Element('object')
    ET.SubElement(obj_elem, 'name').text = str(object_data['label'])
    ET.SubElement(obj_elem, 'pose').text = 'Unspecified'
    ET.SubElement(obj_elem, 'truncated').text = '0'
    ET.SubElement(obj_elem, 'difficult').text = '0'
    
    bndbox = ET.SubElement(obj_elem, 'bndbox')
    ET.SubElement(bndbox, 'xmin').text = str(object_data['x1'])
    ET.SubElement(bndbox, 'ymin').text = str(object_data['y1'])
    ET.SubElement(bndbox, 'xmax').text = str(object_data['x2'])
    ET.SubElement(bndbox, 'ymax').text = str(object_data['y2'])
    
    return obj_elem

def create_voc_xml(filename, objects, output_dir):
    annotation = ET.Element('annotation')
    ET.SubElement(annotation, 'filename').text = os.path.basename(filename)
    
    image = Image.open(filename)
    width, height = image.size
    
    size = ET.SubElement(annotation, 'size')
    ET.SubElement(size, 'width').text = str(width)
    ET.SubElement(size, 'height').text = str(height)
    ET.SubElement(size, 'depth').text = str(len(image.getbands()))
    
    for object_data in objects:
        annotation.append(create_object_element(object_data))
    
    # Create a new XML document
    xml_str = ET.tostring(annotation, encoding='utf-8')
    dom = minidom.parseString(xml_str)
    
    # Pretty-print the XML with indentation
    pretty_xml = dom.toprettyxml(indent='    ')
    
    output_file = os.path.join(output_dir, f"{os.path.splitext(os.path.basename(filename))[0]}.xml")
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(pretty_xml)

# %%
import os
from tqdm.auto import tqdm

output_directory = 'pascal_voc_annotations_bowling_ball'
os.makedirs(output_directory, exist_ok=True)

grouped_df = df.groupby('filename').apply(lambda x: x.to_dict('records')).reset_index(name='objects')
# Out:
# <ipython-input-7-9619a7c25147>:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_df = df.groupby('filename').apply(lambda x: x.to_dict('records')).reset_index(name='objects')

# %%
for row in tqdm(grouped_df.itertuples(index=False), total=len(grouped_df), desc='Generating annotations', unit=' imgs'):
    filename = row.filename
    objects = row.objects
    create_voc_xml(filename, objects, output_directory)
# Out:
# Generating annotations:   0%|          | 0/3852 [00:00<?, ? imgs/s]

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import math

def plot_random_image_with_bounding_boxes(xml_folder, image_folder, num_images, num_columns, resize_width=400):
    # Get the list of XML files in the folder
    xml_files = [file for file in os.listdir(xml_folder) if file.endswith('.xml')]
    
    # Randomly select num_images XML files
    random_xml_files = random.sample(xml_files, num_images)
    
    # Calculate the number of rows needed based on the number of images and columns
    num_rows = math.ceil(num_images / num_columns)
    
    # Create a figure with subplots for each image
    fig, axes = plt.subplots(num_rows, num_columns, figsize=(4 * num_columns, 4 * num_rows))
    fig.subplots_adjust(hspace=0.3, wspace=0.1)
    
    # Flatten the axes array if there is only one row or one column
    if num_rows == 1 or num_columns == 1:
        axes = axes.flatten()
    
    # Iterate over the randomly selected XML files
    for i, xml_file in enumerate(random_xml_files):
        xml_path = os.path.join(xml_folder, xml_file)
        
        # Parse the XML file
        tree = ET.parse(xml_path)
        root = tree.getroot()
        
        # Get the image filename from the XML
        image_filename = root.find('filename').text
        image_path = os.path.join(image_folder, image_filename)
        
        # Read the image
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Get the original image dimensions
        height, width, _ = image.shape
        
        # Calculate the new height while maintaining the aspect ratio
        resize_height = int(height * (resize_width / width))
        
        # Resize the image
        resized_image = cv2.resize(image, (resize_width, resize_height))
        
        # Calculate the scaling factor for resizing
        scale_factor = resize_width / width
        
        # Extract the bounding box information
        for obj in root.findall('object'):
            bndbox = obj.find('bndbox')
            xmin = int(int(bndbox.find('xmin').text) * scale_factor)
            ymin = int(int(bndbox.find('ymin').text) * scale_factor)
            xmax = int(int(bndbox.find('xmax').text) * scale_factor)
            ymax = int(int(bndbox.find('ymax').text) * scale_factor)
            class_id = obj.find('name').text
            
            # Draw the bounding box on the resized image
            cv2.rectangle(resized_image, (xmin, ymin), (xmax, ymax), (0, 255, 0), 2)
            
            # Put the class ID text above the bounding box
            cv2.putText(resized_image, class_id, (xmin, ymin - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        
        # Plot the resized image with bounding boxes and class IDs in the corresponding subplot
        row = i // num_columns
        col = i % num_columns
        axes[row, col].imshow(resized_image)
        axes[row, col].axis('off')
    
    # Display the plots
    plt.show()

# %%
# %matplotlib inline

image_folder = '/workspace/yolo_v8_training/oiv7_full/train/'
xml_folder = 'pascal_voc_annotations_bowling_ball/'

plot_random_image_with_bounding_boxes(xml_folder, image_folder, num_images=9, num_columns=3)
